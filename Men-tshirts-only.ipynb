# %%
'''# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session'''
# Out:
# '# This Python 3 environment comes with many helpful analytics libraries installed\n# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python\n# For example, here\'s several helpful packages to load\n\nimport numpy as np # linear algebra\nimport pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)\n\n# Input data files are available in the read-only "../input/" directory\n# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory\n\nimport os\nfor dirname, _, filenames in os.walk(\'/kaggle/input\'):\n    for filename in filenames:\n        print(os.path.join(dirname, filename))\n\n# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" \n# You can also write temporary files to /kaggle/temp/, but they won\'t be saved outside of the current session'

# %% [markdown]
# ## Importing the training text dataset

# %%
import pandas as pd
train_text=pd.read_csv('/kaggle/input/c/visual-taxonomy/train.csv')
train_text.head()
# Out:
#    id     Category  len      attr_1 attr_2   attr_3   attr_4         attr_5  \
# 0   0  Men Tshirts    5     default  round  printed  default  short sleeves
# 1   1  Men Tshirts    5  multicolor   polo    solid    solid  short sleeves
# 2   2  Men Tshirts    5     default   polo    solid    solid  short sleeves
# 3   3  Men Tshirts    5  multicolor   polo    solid    solid  short sleeves
# 4   4  Men Tshirts    5  multicolor   polo    solid    solid  short sleeves
#
#   attr_6 attr_7 attr_8 attr_9 attr_10
# 0    NaN    NaN    NaN    NaN     NaN
# 1    NaN    NaN    NaN    NaN     NaN
# 2    NaN    NaN    NaN    NaN     NaN
# 3    NaN    NaN    NaN    NaN     NaN
# 4    NaN    NaN    NaN    NaN     NaN

# %%
train_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70213 entries, 0 to 70212
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        70213 non-null  int64
#  1   Category  70213 non-null  object
#  2   len       70213 non-null  int64
#  3   attr_1    51867 non-null  object
#  4   attr_2    55192 non-null  object
#  5   attr_3    54698 non-null  object
#  6   attr_4    59888 non-null  object
#  7   attr_5    56493 non-null  object
#  8   attr_6    38116 non-null  object
#  9   attr_7    41415 non-null  object
#  10  attr_8    37474 non-null  object
#  11  attr_9    33565 non-null  object
#  12  attr_10   24999 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 7.0+ MB

# %% [markdown]
# ## Importing the category attributes file

# %%
categort_attr=pd.read_parquet('/kaggle/input/c/visual-taxonomy/category_attributes.parquet', engine='pyarrow')
categort_attr
# Out:
#               Category  No_of_attribute  \
# 0          Men Tshirts                5
# 1               Sarees               10
# 2               Kurtis                9
# 3        Women Tshirts                8
# 4  Women Tops & Tunics               10
#
#                                       Attribute_list
# 0  [color, neck, pattern, print_or_pattern_type, ...
# 1  [blouse_pattern, border, border_width, color, ...
# 2  [color, fit_shape, length, occasion, ornamenta...
# 3  [color, fit_shape, length, pattern, print_or_p...
# 4  [color, fit_shape, length, neck_collar, ocassi...

# %%
category_len={'Men Tshirts':5,'Sarees':10,'Kurtis':9,'Women Tshirts':8,'Women Tops & Tunics':10}

# %% [markdown]
# ## Importing the test dataset

# %%
test_text=pd.read_csv('/kaggle/input/c/visual-taxonomy/test.csv')
test_text.head()
# Out:
#    id     Category
# 0   0  Men Tshirts
# 1   1  Men Tshirts
# 2   2  Men Tshirts
# 3   3  Men Tshirts
# 4   4  Men Tshirts

# %% [markdown]
# ### Import the npy training files for Mens Tshirt

# %%
train_mens=train_text[train_text['Category']=='Men Tshirts']
train_mens
# Out:
#         id     Category  len      attr_1 attr_2   attr_3   attr_4  \
# 0        0  Men Tshirts    5     default  round  printed  default
# 1        1  Men Tshirts    5  multicolor   polo    solid    solid
# 2        2  Men Tshirts    5     default   polo    solid    solid
# 3        3  Men Tshirts    5  multicolor   polo    solid    solid
# 4        4  Men Tshirts    5  multicolor   polo    solid    solid
# ...    ...          ...  ...         ...    ...      ...      ...
# 7262  7424  Men Tshirts    5         NaN    NaN  printed      NaN
# 7263  7425  Men Tshirts    5         NaN  round      NaN      NaN
# 7264  7426  Men Tshirts    5         NaN    NaN      NaN  default
# 7265  7429  Men Tshirts    5         NaN    NaN      NaN  default
# 7266  7430  Men Tshirts    5         NaN    NaN      NaN      NaN
#
#              attr_5 attr_6 attr_7 attr_8 attr_9 attr_10
# 0     short sleeves    NaN    NaN    NaN    NaN     NaN
# 1     short sleeves    NaN    NaN    NaN    NaN     NaN
# 2     short sleeves    NaN    NaN    NaN    NaN     NaN
# 3     short sleeves    NaN    NaN    NaN    NaN     NaN
# 4     short sleeves    NaN    NaN    NaN    NaN     NaN
# ...             ...    ...    ...    ...    ...     ...
# 7262            NaN    NaN    NaN    NaN    NaN     NaN
# 7263            NaN    NaN    NaN    NaN    NaN     NaN
# 7264  short sleeves    NaN    NaN    NaN    NaN     NaN
# 7265            NaN    NaN    NaN    NaN    NaN     NaN
# 7266  short sleeves    NaN    NaN    NaN    NaN     NaN
#
# [7267 rows x 13 columns]

# %%
train_mens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 0 to 7266
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7267 non-null   int64
#  1   Category  7267 non-null   object
#  2   len       7267 non-null   int64
#  3   attr_1    6010 non-null   object
#  4   attr_2    6144 non-null   object
#  5   attr_3    5791 non-null   object
#  6   attr_4    5949 non-null   object
#  7   attr_5    5977 non-null   object
#  8   attr_6    0 non-null      object
#  9   attr_7    0 non-null      object
#  10  attr_8    0 non-null      object
#  11  attr_9    0 non-null      object
#  12  attr_10   0 non-null      object
# dtypes: int64(2), object(11)
# memory usage: 794.8+ KB

# %%
import numpy as np
image_features=np.load('/kaggle/input/feature-npy-files/train_features_26k.npy') 

# Flatten the image features to (32, 768) for each sample
image_features = image_features.reshape((image_features.shape[0], -1))
image_features.shape
# Out:
# (26000, 768)

# %%
image_features=image_features[:7267] #mens tshirt only
image_features.shape
# Out:
# (7267, 768)

# %% [markdown]
# ## Training a combined model

# %%
# Checking for NaNs in the relevant columns
print(train_text[['attr_1', 'attr_2', 'attr_3', 'attr_4', 'attr_5', 'attr_6', 'attr_7', 'attr_8', 'attr_9', 'attr_10']].isna().sum())
# Out:
# attr_1     18346
# attr_2     15021
# attr_3     15515
# attr_4     10325
# attr_5     13720
# attr_6     32097
# attr_7     28798
# attr_8     32739
# attr_9     36648
# attr_10    45214
# dtype: int64

# %%
train_text = train_mens.fillna('dummy_value')

# %%
# Calculate number of unique classes for each attribute
num_attr_1_classes = train_text['attr_1'].nunique()
num_attr_2_classes = train_text['attr_2'].nunique()
num_attr_3_classes = train_text['attr_3'].nunique()
num_attr_4_classes = train_text['attr_4'].nunique()
num_attr_5_classes = train_text['attr_5'].nunique()
num_attr_6_classes = train_text['attr_6'].nunique()
num_attr_7_classes = train_text['attr_7'].nunique()
num_attr_8_classes = train_text['attr_8'].nunique()
num_attr_9_classes = train_text['attr_9'].nunique()
num_attr_10_classes = train_text['attr_10'].nunique()

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import numpy as np

# Function to encode labels and convert to correct dtype
def encode_labels(column):
    label_encoder = LabelEncoder()
    integer_encoded = label_encoder.fit_transform(train_text[column].fillna('dummy_value'))
    onehot_encoded = to_categorical(integer_encoded)
    onehot_encoded = onehot_encoded.astype('float32')  # Ensure the correct dtype
    return onehot_encoded, label_encoder

# Encode the labels for each attribute
attr_1_labels, encoder_attr_1 = encode_labels('attr_1')
attr_2_labels, encoder_attr_2 = encode_labels('attr_2')
attr_3_labels, encoder_attr_3 = encode_labels('attr_3')
attr_4_labels, encoder_attr_4 = encode_labels('attr_4')
attr_5_labels, encoder_attr_5 = encode_labels('attr_5')
attr_6_labels, encoder_attr_6 = encode_labels('attr_6')
attr_7_labels, encoder_attr_7 = encode_labels('attr_7')
attr_8_labels, encoder_attr_8 = encode_labels('attr_8')
attr_9_labels, encoder_attr_9 = encode_labels('attr_9')
attr_10_labels, encoder_attr_10 = encode_labels('attr_10')

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the 'Category' column
train_text['Category'] = label_encoder.fit_transform(train_text['Category'])

# %%
# Flatten the image features to (32, 768) for each sample
image_features = image_features.reshape((image_features.shape[0], -1))

# Redefine the model with correct input shape
from tensorflow.keras.layers import Input, Dense, Concatenate, Flatten
from tensorflow.keras.models import Model

# Input layers
image_input = Input(shape=(768,), name='image_input')  # For ViT features
tabular_input = Input(shape=(2,), name='tabular_input')  # For tabular data (2 features)

# Dense layers for image features
x1 = Dense(128, activation='relu')(image_input)

# Dense layers for tabular features
x2 = Dense(128, activation='relu')(tabular_input)

# Concatenate image and tabular inputs
x = Concatenate()([x1, x2])

# Further dense layers after concatenation
x = Dense(128, activation='relu')(x)

# Output layers for attributes
output_1 = Dense(num_attr_1_classes, activation='softmax', name='attr_1')(x)
output_2 = Dense(num_attr_2_classes, activation='softmax', name='attr_2')(x)
output_3 = Dense(num_attr_3_classes, activation='softmax', name='attr_3')(x)
output_4 = Dense(num_attr_4_classes, activation='softmax', name='attr_4')(x)
output_5 = Dense(num_attr_5_classes, activation='softmax', name='attr_5')(x)
output_6 = Dense(num_attr_6_classes, activation='softmax', name='attr_6')(x)
output_7 = Dense(num_attr_7_classes, activation='softmax', name='attr_7')(x)
output_8 = Dense(num_attr_8_classes, activation='softmax', name='attr_8')(x)
output_9 = Dense(num_attr_9_classes, activation='softmax', name='attr_9')(x)
output_10 = Dense(num_attr_10_classes, activation='softmax', name='attr_10')(x)

# Build the model
model = Model(inputs=[image_input, tabular_input], 
              outputs=[output_1, output_2, output_3, output_4, output_5, 
                       output_6, output_7, output_8, output_9, output_10])

# Compile the model
model.compile(optimizer='adam', 
              loss={'attr_1': 'categorical_crossentropy',
                    'attr_2': 'categorical_crossentropy',
                    'attr_3': 'categorical_crossentropy',
                    'attr_4': 'categorical_crossentropy',
                    'attr_5': 'categorical_crossentropy',
                    'attr_6': 'categorical_crossentropy',
                    'attr_7': 'categorical_crossentropy',
                    'attr_8': 'categorical_crossentropy',
                    'attr_9': 'categorical_crossentropy',
                    'attr_10': 'categorical_crossentropy'},
              metrics={'attr_1': 'accuracy',
                       'attr_2': 'accuracy',
                       'attr_3': 'accuracy',
                       'attr_4': 'accuracy',
                       'attr_5': 'accuracy',
                       'attr_6': 'accuracy',
                       'attr_7': 'accuracy',
                       'attr_8': 'accuracy',
                       'attr_9': 'accuracy',
                       'attr_10': 'accuracy'})  # Metrics for each output

# Train the model
history = model.fit([image_features, train_text.iloc[:len(image_features), :2].values], 
                    [attr_1_labels, attr_2_labels, attr_3_labels, 
                     attr_4_labels, attr_5_labels, attr_6_labels, 
                     attr_7_labels, attr_8_labels, attr_9_labels, 
                     attr_10_labels],
                    epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/keras/src/losses/losses.py:22: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2317 - attr_2_accuracy: 0.4526 - attr_3_accuracy: 0.4326 - attr_4_accuracy: 0.3589 - attr_5_accuracy: 0.7610 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 202.3828 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.5406 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.6788 - val_attr_5_accuracy: 0.0138 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 32.9125
# Epoch 2/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2434 - attr_2_accuracy: 0.4671 - attr_3_accuracy: 0.4389 - attr_4_accuracy: 0.4078 - attr_5_accuracy: 0.7605 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 23.7821 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0550 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.5777 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 74.9613
# Epoch 3/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2822 - attr_2_accuracy: 0.4700 - attr_3_accuracy: 0.4373 - attr_4_accuracy: 0.4473 - attr_5_accuracy: 0.8082 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 23.0281 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0550 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.0750 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 116.2535
# Epoch 4/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2875 - attr_2_accuracy: 0.4710 - attr_3_accuracy: 0.4402 - attr_4_accuracy: 0.4129 - attr_5_accuracy: 0.8146 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 18.3725 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 103.1013
# Epoch 5/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2745 - attr_2_accuracy: 0.4785 - attr_3_accuracy: 0.4668 - attr_4_accuracy: 0.4367 - attr_5_accuracy: 0.8094 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 16.8504 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4161 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.6788 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 42.0280
# Epoch 6/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2744 - attr_2_accuracy: 0.4987 - attr_3_accuracy: 0.4786 - attr_4_accuracy: 0.4461 - attr_5_accuracy: 0.8106 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 13.9599 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4312 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 98.2077
# Epoch 7/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2848 - attr_2_accuracy: 0.4940 - attr_3_accuracy: 0.4447 - attr_4_accuracy: 0.4371 - attr_5_accuracy: 0.8160 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 14.5380 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.1816 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 29.6493
# Epoch 8/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2817 - attr_2_accuracy: 0.5393 - attr_3_accuracy: 0.4822 - attr_4_accuracy: 0.4839 - attr_5_accuracy: 0.8088 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 9.9682 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0702 - val_attr_2_accuracy: 0.4072 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.0818 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 35.0149
# Epoch 9/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3019 - attr_2_accuracy: 0.5385 - attr_3_accuracy: 0.5259 - attr_4_accuracy: 0.4914 - attr_5_accuracy: 0.8325 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 9.7039 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.7008 - val_attr_2_accuracy: 0.4161 - val_attr_3_accuracy: 0.3219 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 32.5142
# Epoch 10/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2966 - attr_2_accuracy: 0.6032 - attr_3_accuracy: 0.5462 - attr_4_accuracy: 0.5150 - attr_5_accuracy: 0.8371 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 9.0264 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0550 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.0763 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 62.8857
# Epoch 11/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3265 - attr_2_accuracy: 0.6432 - attr_3_accuracy: 0.5791 - attr_4_accuracy: 0.5317 - attr_5_accuracy: 0.8342 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 7.4725 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0922 - val_attr_2_accuracy: 0.4023 - val_attr_3_accuracy: 0.3659 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 19.6582
# Epoch 12/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3172 - attr_2_accuracy: 0.6148 - attr_3_accuracy: 0.5449 - attr_4_accuracy: 0.5336 - attr_5_accuracy: 0.8223 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 7.7743 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.3845 - val_attr_2_accuracy: 0.2779 - val_attr_3_accuracy: 0.0715 - val_attr_4_accuracy: 0.2510 - val_attr_5_accuracy: 0.5144 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 10.7233
# Epoch 13/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3331 - attr_2_accuracy: 0.6775 - attr_3_accuracy: 0.5943 - attr_4_accuracy: 0.5542 - attr_5_accuracy: 0.8306 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 6.5964 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0942 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.4243 - val_attr_4_accuracy: 0.0750 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 23.6664
# Epoch 14/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3215 - attr_2_accuracy: 0.6308 - attr_3_accuracy: 0.5861 - attr_4_accuracy: 0.5635 - attr_5_accuracy: 0.8287 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 7.1980 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.6265 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.0901 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 29.0668
# Epoch 15/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3352 - attr_2_accuracy: 0.6867 - attr_3_accuracy: 0.6372 - attr_4_accuracy: 0.5828 - attr_5_accuracy: 0.8288 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 6.2947 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0757 - val_attr_2_accuracy: 0.1190 - val_attr_3_accuracy: 0.5571 - val_attr_4_accuracy: 0.6492 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 11.1931
# Epoch 16/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3334 - attr_2_accuracy: 0.6927 - attr_3_accuracy: 0.6569 - attr_4_accuracy: 0.6072 - attr_5_accuracy: 0.8623 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.7066 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0956 - val_attr_2_accuracy: 0.2435 - val_attr_3_accuracy: 0.3858 - val_attr_4_accuracy: 0.0750 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 13.4700
# Epoch 17/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3442 - attr_2_accuracy: 0.6811 - attr_3_accuracy: 0.6537 - attr_4_accuracy: 0.5944 - attr_5_accuracy: 0.8454 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.4682 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.6905 - val_attr_2_accuracy: 0.1816 - val_attr_3_accuracy: 0.2001 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.5935 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 13.1471
# Epoch 18/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3205 - attr_2_accuracy: 0.6987 - attr_3_accuracy: 0.6826 - attr_4_accuracy: 0.6207 - attr_5_accuracy: 0.8491 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.3699 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.6018 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.3528 - val_attr_4_accuracy: 0.1713 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 18.9520
# Epoch 19/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3505 - attr_2_accuracy: 0.7177 - attr_3_accuracy: 0.6766 - attr_4_accuracy: 0.6097 - attr_5_accuracy: 0.8583 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.3875 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0887 - val_attr_2_accuracy: 0.3941 - val_attr_3_accuracy: 0.3274 - val_attr_4_accuracy: 0.0750 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 11.2408
# Epoch 20/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3436 - attr_2_accuracy: 0.7231 - attr_3_accuracy: 0.6879 - attr_4_accuracy: 0.6392 - attr_5_accuracy: 0.8401 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.1276 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.7001 - val_attr_2_accuracy: 0.3177 - val_attr_3_accuracy: 0.1884 - val_attr_4_accuracy: 0.0763 - val_attr_5_accuracy: 0.5475 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 9.8946
# Epoch 21/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3460 - attr_2_accuracy: 0.7197 - attr_3_accuracy: 0.6589 - attr_4_accuracy: 0.6077 - attr_5_accuracy: 0.8374 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.4092 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.3267 - val_attr_2_accuracy: 0.2600 - val_attr_3_accuracy: 0.1018 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 14.1697
# Epoch 22/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3615 - attr_2_accuracy: 0.7368 - attr_3_accuracy: 0.6907 - attr_4_accuracy: 0.6367 - attr_5_accuracy: 0.8442 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.9443 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.3494 - val_attr_3_accuracy: 0.2036 - val_attr_4_accuracy: 0.4849 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 12.6805
# Epoch 23/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3535 - attr_2_accuracy: 0.7475 - attr_3_accuracy: 0.6973 - attr_4_accuracy: 0.6434 - attr_5_accuracy: 0.8539 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.9647 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.6884 - val_attr_2_accuracy: 0.5206 - val_attr_3_accuracy: 0.3102 - val_attr_4_accuracy: 0.0750 - val_attr_5_accuracy: 0.4615 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.5534
# Epoch 24/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3567 - attr_2_accuracy: 0.7290 - attr_3_accuracy: 0.6875 - attr_4_accuracy: 0.6341 - attr_5_accuracy: 0.8574 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.7748 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0715 - val_attr_2_accuracy: 0.3432 - val_attr_3_accuracy: 0.3274 - val_attr_4_accuracy: 0.1651 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 21.1939
# Epoch 25/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3423 - attr_2_accuracy: 0.7507 - attr_3_accuracy: 0.6990 - attr_4_accuracy: 0.6360 - attr_5_accuracy: 0.8502 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.7603 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.2895 - val_attr_2_accuracy: 0.2428 - val_attr_3_accuracy: 0.2387 - val_attr_4_accuracy: 0.0915 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 10.0813
# Epoch 26/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3604 - attr_2_accuracy: 0.7735 - attr_3_accuracy: 0.7279 - attr_4_accuracy: 0.6615 - attr_5_accuracy: 0.8773 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.1908 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.4821 - val_attr_3_accuracy: 0.5770 - val_attr_4_accuracy: 0.1437 - val_attr_5_accuracy: 0.4801 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.4723
# Epoch 27/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3709 - attr_2_accuracy: 0.7359 - attr_3_accuracy: 0.6808 - attr_4_accuracy: 0.6573 - attr_5_accuracy: 0.8696 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.5631 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0550 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.0880 - val_attr_4_accuracy: 0.2620 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 11.6519
# Epoch 28/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3509 - attr_2_accuracy: 0.7021 - attr_3_accuracy: 0.6812 - attr_4_accuracy: 0.6498 - attr_5_accuracy: 0.8625 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.6035 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.3081 - val_attr_3_accuracy: 0.1389 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 13.1313
# Epoch 29/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3519 - attr_2_accuracy: 0.7420 - attr_3_accuracy: 0.6985 - attr_4_accuracy: 0.5760 - attr_5_accuracy: 0.8788 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.4095 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0956 - val_attr_2_accuracy: 0.3480 - val_attr_3_accuracy: 0.2792 - val_attr_4_accuracy: 0.0894 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.3344
# Epoch 30/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3769 - attr_2_accuracy: 0.7546 - attr_3_accuracy: 0.7140 - attr_4_accuracy: 0.6809 - attr_5_accuracy: 0.8728 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.1263 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0832 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.0750 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.0651
# Epoch 31/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3561 - attr_2_accuracy: 0.6909 - attr_3_accuracy: 0.6632 - attr_4_accuracy: 0.6155 - attr_5_accuracy: 0.8748 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.4468 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0784 - val_attr_2_accuracy: 0.2091 - val_attr_3_accuracy: 0.1279 - val_attr_4_accuracy: 0.0894 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.6896
# Epoch 32/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3869 - attr_2_accuracy: 0.7792 - attr_3_accuracy: 0.7320 - attr_4_accuracy: 0.6907 - attr_5_accuracy: 0.8718 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 3.9074 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.1562
# Epoch 33/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3736 - attr_2_accuracy: 0.6795 - attr_3_accuracy: 0.6214 - attr_4_accuracy: 0.5655 - attr_5_accuracy: 0.8746 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.4923 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.4072 - val_attr_3_accuracy: 0.3583 - val_attr_4_accuracy: 0.1878 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.1963
# Epoch 34/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3882 - attr_2_accuracy: 0.7787 - attr_3_accuracy: 0.7405 - attr_4_accuracy: 0.6839 - attr_5_accuracy: 0.8742 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 3.9752 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.3012 - val_attr_3_accuracy: 0.2490 - val_attr_4_accuracy: 0.1465 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.2640
# Epoch 35/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3883 - attr_2_accuracy: 0.7089 - attr_3_accuracy: 0.6548 - attr_4_accuracy: 0.6014 - attr_5_accuracy: 0.8674 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.2400 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0777 - val_attr_2_accuracy: 0.2373 - val_attr_3_accuracy: 0.1809 - val_attr_4_accuracy: 0.1135 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 9.5302
# Epoch 36/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3703 - attr_2_accuracy: 0.6429 - attr_3_accuracy: 0.5982 - attr_4_accuracy: 0.5421 - attr_5_accuracy: 0.8737 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.5015 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4023 - val_attr_3_accuracy: 0.3453 - val_attr_4_accuracy: 0.1864 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.7027
# Epoch 37/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.4038 - attr_2_accuracy: 0.7665 - attr_3_accuracy: 0.7232 - attr_4_accuracy: 0.6771 - attr_5_accuracy: 0.8733 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 3.9922 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0578 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 18.1600
# Epoch 38/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3739 - attr_2_accuracy: 0.5626 - attr_3_accuracy: 0.5211 - attr_4_accuracy: 0.4638 - attr_5_accuracy: 0.8810 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.7857 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.0433 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 13.6507
# Epoch 39/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3481 - attr_2_accuracy: 0.5824 - attr_3_accuracy: 0.5382 - attr_4_accuracy: 0.4767 - attr_5_accuracy: 0.8798 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.7220 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.3267 - val_attr_3_accuracy: 0.2772 - val_attr_4_accuracy: 0.1568 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.9342
# Epoch 40/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.4037 - attr_2_accuracy: 0.7532 - attr_3_accuracy: 0.7024 - attr_4_accuracy: 0.6522 - attr_5_accuracy: 0.8722 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.0914 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.4023 - val_attr_3_accuracy: 0.3563 - val_attr_4_accuracy: 0.1884 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.1456
# Epoch 41/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.4047 - attr_2_accuracy: 0.7413 - attr_3_accuracy: 0.7106 - attr_4_accuracy: 0.6476 - attr_5_accuracy: 0.8683 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.1028 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.9948
# Epoch 42/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3933 - attr_2_accuracy: 0.7707 - attr_3_accuracy: 0.7323 - attr_4_accuracy: 0.6618 - attr_5_accuracy: 0.8816 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 3.9615 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4147 - val_attr_3_accuracy: 0.3652 - val_attr_4_accuracy: 0.1857 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.0284
# Epoch 43/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3926 - attr_2_accuracy: 0.7656 - attr_3_accuracy: 0.7257 - attr_4_accuracy: 0.6691 - attr_5_accuracy: 0.8807 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 3.9370 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0777 - val_attr_2_accuracy: 0.3920 - val_attr_3_accuracy: 0.3411 - val_attr_4_accuracy: 0.1884 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.3703
# Epoch 44/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.4030 - attr_2_accuracy: 0.7589 - attr_3_accuracy: 0.7003 - attr_4_accuracy: 0.6424 - attr_5_accuracy: 0.8754 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.0036 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0743 - val_attr_2_accuracy: 0.1816 - val_attr_3_accuracy: 0.1602 - val_attr_4_accuracy: 0.1032 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 12.8194
# Epoch 45/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3748 - attr_2_accuracy: 0.6445 - attr_3_accuracy: 0.6012 - attr_4_accuracy: 0.5429 - attr_5_accuracy: 0.8758 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.4710 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4140 - val_attr_3_accuracy: 0.3645 - val_attr_4_accuracy: 0.1857 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.2160
# Epoch 46/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3835 - attr_2_accuracy: 0.7548 - attr_3_accuracy: 0.7025 - attr_4_accuracy: 0.6499 - attr_5_accuracy: 0.8723 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.0589 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0784 - val_attr_2_accuracy: 0.3370 - val_attr_3_accuracy: 0.3040 - val_attr_4_accuracy: 0.1678 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 9.2333
# Epoch 47/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.4020 - attr_2_accuracy: 0.8018 - attr_3_accuracy: 0.7451 - attr_4_accuracy: 0.6918 - attr_5_accuracy: 0.8772 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 3.8169 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0777 - val_attr_2_accuracy: 0.3404 - val_attr_3_accuracy: 0.3067 - val_attr_4_accuracy: 0.1713 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 9.1112
# Epoch 48/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3828 - attr_2_accuracy: 0.7646 - attr_3_accuracy: 0.7253 - attr_4_accuracy: 0.6586 - attr_5_accuracy: 0.8778 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 3.9670 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0729 - val_attr_2_accuracy: 0.2270 - val_attr_3_accuracy: 0.2015 - val_attr_4_accuracy: 0.1245 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 12.0050
# Epoch 49/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.4005 - attr_2_accuracy: 0.7886 - attr_3_accuracy: 0.7540 - attr_4_accuracy: 0.6997 - attr_5_accuracy: 0.8734 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 3.8132 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.3473 - val_attr_3_accuracy: 0.3095 - val_attr_4_accuracy: 0.1719 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.9977
# Epoch 50/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3810 - attr_2_accuracy: 0.7653 - attr_3_accuracy: 0.7221 - attr_4_accuracy: 0.6749 - attr_5_accuracy: 0.8791 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 3.9428 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0777 - val_attr_2_accuracy: 0.3418 - val_attr_3_accuracy: 0.3067 - val_attr_4_accuracy: 0.1699 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 9.1897

# %% [markdown]
# ## Test the model

# %%
test_text[test_text['Category']=='Men Tshirts']
# Out:
#         id     Category
# 0        0  Men Tshirts
# 1        1  Men Tshirts
# 2        2  Men Tshirts
# 3        3  Men Tshirts
# 4        4  Men Tshirts
# ...    ...          ...
# 3782  3782  Men Tshirts
# 3783  3783  Men Tshirts
# 3784  3784  Men Tshirts
# 3785  3785  Men Tshirts
# 3786  3786  Men Tshirts
#
# [3787 rows x 2 columns]

# %%
test_features=np.load('/kaggle/input/feature-npy-files/test_features_30500.npy') 
# Reshape the test_features to match the expected input shape
test_features = test_features.reshape(test_features.shape[0], -1)
test_features.shape
# Out:
# (30489, 768)

# %%
test_features=test_features[:3787] #men tshirts

# %%
test_features.shape
# Out:
# (3787, 768)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Encode categorical columns
categorical_columns = test_text.select_dtypes(include=['object']).columns
label_encoder = LabelEncoder()
for i in categorical_columns:
    test_text[i] = label_encoder.fit_transform(test_text[i])

# %%
predicted_values=len(test_features)

# Convert to numpy arrays
test_tabular_features = test_text[:predicted_values].values

# %%
print("Shape of test_tabular_features:", test_tabular_features.shape)
# Out:
# Shape of test_tabular_features: (3787, 2)

# %%
# Get predictions from the trained model
predictions = model.predict([test_features[:predicted_values], test_tabular_features])
# Out:
#  17/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /opt/conda/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# /opt/conda/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(

# %%
# Extract the class with the highest probability for each attribute prediction
predicted_labels = []
for i, prediction in enumerate(predictions):
    predicted_labels.append(np.argmax(prediction, axis=1))

# Display the predicted labels for each attribute
for i, label in enumerate(predicted_labels):
    print(f"Predicted Labels for Attribute {i+1}: {label}")
# Out:
# Predicted Labels for Attribute 1: [1 1 1 ... 3 3 1]
# Predicted Labels for Attribute 2: [2 2 2 ... 1 1 1]
# Predicted Labels for Attribute 3: [1 1 1 ... 2 2 2]
# Predicted Labels for Attribute 4: [0 0 0 ... 2 2 2]
# Predicted Labels for Attribute 5: [2 2 2 ... 2 2 2]
# Predicted Labels for Attribute 6: [0 0 0 ... 0 0 0]
# Predicted Labels for Attribute 7: [0 0 0 ... 0 0 0]
# Predicted Labels for Attribute 8: [0 0 0 ... 0 0 0]
# Predicted Labels for Attribute 9: [0 0 0 ... 0 0 0]
# Predicted Labels for Attribute 10: [0 0 0 ... 0 0 0]

# %%
import pandas as pd
import numpy as np

# Number of test samples
total_test_samples = 30205  # Total number of test rows
#predicted_samples = 4440    # Number of predicted samples

# Create a DataFrame with NaN for all rows initially
submission_df = pd.DataFrame(np.nan, index=range(total_test_samples), columns=['id','Category','len',
    'Attribute_1', 'Attribute_2', 'Attribute_3', 'Attribute_4', 'Attribute_5', 
    'Attribute_6', 'Attribute_7', 'Attribute_8', 'Attribute_9', 'Attribute_10'
])

# %%
test_text=pd.read_csv('/kaggle/input/c/visual-taxonomy/test.csv')
test_text.head()
# Out:
#    id     Category
# 0   0  Men Tshirts
# 1   1  Men Tshirts
# 2   2  Men Tshirts
# 3   3  Men Tshirts
# 4   4  Men Tshirts

# %%
submission_df.iloc[:30205,0] = test_text.iloc[:,0]
submission_df.iloc[:30205,1] = test_text.iloc[:,1]
# Out:
# /tmp/ipykernel_31/4028425247.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['Men Tshirts' 'Men Tshirts' 'Men Tshirts' ... 'Women Tops & Tunics'
#  'Women Tops & Tunics' 'Women Tops & Tunics']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:30205,1] = test_text.iloc[:,1]

# %%
submission_df.loc[:, 'len'] = submission_df['Category'].map(category_len)

# %%
# Reverse the encoding of predicted labels using LabelEncoder's inverse_transform
reversed_attr_1 = encoder_attr_1.inverse_transform(predicted_labels[0])  # For Attribute 1
reversed_attr_2 = encoder_attr_2.inverse_transform(predicted_labels[1])  # For Attribute 2
reversed_attr_3 = encoder_attr_3.inverse_transform(predicted_labels[2])  # For Attribute 3
reversed_attr_4 = encoder_attr_4.inverse_transform(predicted_labels[3])  # For Attribute 4
reversed_attr_5 = encoder_attr_5.inverse_transform(predicted_labels[4])  # For Attribute 5
reversed_attr_6 = encoder_attr_6.inverse_transform(predicted_labels[5])  # For Attribute 6
reversed_attr_7 = encoder_attr_7.inverse_transform(predicted_labels[6])  # For Attribute 7
reversed_attr_8 = encoder_attr_8.inverse_transform(predicted_labels[7])  # For Attribute 8
reversed_attr_9 = encoder_attr_9.inverse_transform(predicted_labels[8])  # For Attribute 9
reversed_attr_10 = encoder_attr_10.inverse_transform(predicted_labels[9])  # For Attribute 10

# %%
# Prepare the submission DataFrame
submission_df.iloc[:predicted_values, 3] = reversed_attr_1
submission_df.iloc[:predicted_values, 4] = reversed_attr_2
submission_df.iloc[:predicted_values, 5] = reversed_attr_3
submission_df.iloc[:predicted_values, 6] = reversed_attr_4
submission_df.iloc[:predicted_values, 7] = reversed_attr_5
submission_df.iloc[:predicted_values, 8] = reversed_attr_6
submission_df.iloc[:predicted_values, 9] = reversed_attr_7
submission_df.iloc[:predicted_values, 10] = reversed_attr_8
submission_df.iloc[:predicted_values, 11] = reversed_attr_9
submission_df.iloc[:predicted_values, 12] = reversed_attr_10

# Fill the remaining rows with NaN
submission_df.iloc[predicted_values:] = np.nan
# Out:
# /tmp/ipykernel_31/4084899079.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['default' 'default' 'default' ... 'multicolor' 'multicolor' 'default']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 3] = reversed_attr_1
# /tmp/ipykernel_31/4084899079.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['round' 'round' 'round' ... 'polo' 'polo' 'polo']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 4] = reversed_attr_2
# /tmp/ipykernel_31/4084899079.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['printed' 'printed' 'printed' ... 'solid' 'solid' 'solid']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 5] = reversed_attr_3
# /tmp/ipykernel_31/4084899079.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['default' 'default' 'default' ... 'solid' 'solid' 'solid']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 6] = reversed_attr_4
# /tmp/ipykernel_31/4084899079.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['short sleeves' 'short sleeves' 'short sleeves' ... 'short sleeves'
#  'short sleeves' 'short sleeves']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 7] = reversed_attr_5
# /tmp/ipykernel_31/4084899079.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 8] = reversed_attr_6
# /tmp/ipykernel_31/4084899079.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 9] = reversed_attr_7
# /tmp/ipykernel_31/4084899079.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 10] = reversed_attr_8
# /tmp/ipykernel_31/4084899079.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 11] = reversed_attr_9
# /tmp/ipykernel_31/4084899079.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 12] = reversed_attr_10

# %%
submission_df=submission_df.iloc[:30205,:]

# %%
submission_df
# Out:
#         id     Category  len Attribute_1  Attribute_2 Attribute_3 Attribute_4  \
# 0      0.0  Men Tshirts  5.0     default        round     printed     default
# 1      1.0  Men Tshirts  5.0     default        round     printed     default
# 2      2.0  Men Tshirts  5.0     default        round     printed     default
# 3      3.0  Men Tshirts  5.0  multicolor         polo       solid       solid
# 4      4.0  Men Tshirts  5.0     default  dummy_value       solid       solid
# ...    ...          ...  ...         ...          ...         ...         ...
# 30200  NaN          NaN  NaN         NaN          NaN         NaN         NaN
# 30201  NaN          NaN  NaN         NaN          NaN         NaN         NaN
# 30202  NaN          NaN  NaN         NaN          NaN         NaN         NaN
# 30203  NaN          NaN  NaN         NaN          NaN         NaN         NaN
# 30204  NaN          NaN  NaN         NaN          NaN         NaN         NaN
#
#          Attribute_5  Attribute_6  Attribute_7  Attribute_8  Attribute_9  \
# 0      short sleeves  dummy_value  dummy_value  dummy_value  dummy_value
# 1      short sleeves  dummy_value  dummy_value  dummy_value  dummy_value
# 2      short sleeves  dummy_value  dummy_value  dummy_value  dummy_value
# 3      short sleeves  dummy_value  dummy_value  dummy_value  dummy_value
# 4      short sleeves  dummy_value  dummy_value  dummy_value  dummy_value
# ...              ...          ...          ...          ...          ...
# 30200            NaN          NaN          NaN          NaN          NaN
# 30201            NaN          NaN          NaN          NaN          NaN
# 30202            NaN          NaN          NaN          NaN          NaN
# 30203            NaN          NaN          NaN          NaN          NaN
# 30204            NaN          NaN          NaN          NaN          NaN
#
#       Attribute_10
# 0      dummy_value
# 1      dummy_value
# 2      dummy_value
# 3      dummy_value
# 4      dummy_value
# ...            ...
# 30200          NaN
# 30201          NaN
# 30202          NaN
# 30203          NaN
# 30204          NaN
#
# [30205 rows x 13 columns]

# %%
submission_df.fillna('nu', inplace=True)
# Out:
# /tmp/ipykernel_31/2203038571.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nu' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.fillna('nu', inplace=True)

# %%
submission_df.iloc[:30205,0] = test_text.iloc[:,0]
submission_df.iloc[:30205,1] = test_text.iloc[:,1]

# %%
# Rename columns
submission_df.rename(columns={
    'Attribute_1': 'attr_1',
    'Attribute_2': 'attr_2',
    'Attribute_3': 'attr_3',
    'Attribute_4': 'attr_4',
    'Attribute_5': 'attr_5',
    'Attribute_6': 'attr_6',
    'Attribute_7': 'attr_7',
    'Attribute_8': 'attr_8',
    'Attribute_9': 'attr_9',
    'Attribute_10': 'attr_10',
}, inplace=True)

# %%
submission_df
# Out:
#           id             Category  len      attr_1       attr_2   attr_3  \
# 0          0          Men Tshirts  5.0     default        round  printed
# 1          1          Men Tshirts  5.0     default        round  printed
# 2          2          Men Tshirts  5.0     default        round  printed
# 3          3          Men Tshirts  5.0  multicolor         polo    solid
# 4          4          Men Tshirts  5.0     default  dummy_value    solid
# ...      ...                  ...  ...         ...          ...      ...
# 30200  30484  Women Tops & Tunics   nu          nu           nu       nu
# 30201  30485  Women Tops & Tunics   nu          nu           nu       nu
# 30202  30486  Women Tops & Tunics   nu          nu           nu       nu
# 30203  30487  Women Tops & Tunics   nu          nu           nu       nu
# 30204  30488  Women Tops & Tunics   nu          nu           nu       nu
#
#         attr_4         attr_5       attr_6       attr_7       attr_8  \
# 0      default  short sleeves  dummy_value  dummy_value  dummy_value
# 1      default  short sleeves  dummy_value  dummy_value  dummy_value
# 2      default  short sleeves  dummy_value  dummy_value  dummy_value
# 3        solid  short sleeves  dummy_value  dummy_value  dummy_value
# 4        solid  short sleeves  dummy_value  dummy_value  dummy_value
# ...        ...            ...          ...          ...          ...
# 30200       nu             nu           nu           nu           nu
# 30201       nu             nu           nu           nu           nu
# 30202       nu             nu           nu           nu           nu
# 30203       nu             nu           nu           nu           nu
# 30204       nu             nu           nu           nu           nu
#
#             attr_9      attr_10
# 0      dummy_value  dummy_value
# 1      dummy_value  dummy_value
# 2      dummy_value  dummy_value
# 3      dummy_value  dummy_value
# 4      dummy_value  dummy_value
# ...            ...          ...
# 30200           nu           nu
# 30201           nu           nu
# 30202           nu           nu
# 30203           nu           nu
# 30204           nu           nu
#
# [30205 rows x 13 columns]

# %%
# Save the DataFrame to a CSV file
submission_file = 'submission_MEN_TSHIRTS.csv'
submission_df.to_csv(submission_file, index=False)

print("Submission file created successfully!")
# Out:
# Submission file created successfully!
