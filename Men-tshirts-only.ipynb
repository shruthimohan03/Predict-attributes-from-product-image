# %%
'''# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session'''
# Out:
# '# This Python 3 environment comes with many helpful analytics libraries installed\n# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python\n# For example, here\'s several helpful packages to load\n\nimport numpy as np # linear algebra\nimport pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)\n\n# Input data files are available in the read-only "../input/" directory\n# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory\n\nimport os\nfor dirname, _, filenames in os.walk(\'/kaggle/input\'):\n    for filename in filenames:\n        print(os.path.join(dirname, filename))\n\n# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" \n# You can also write temporary files to /kaggle/temp/, but they won\'t be saved outside of the current session'

# %% [markdown]
# ## Importing the training text dataset

# %%
import pandas as pd
train_text=pd.read_csv('/kaggle/input/c/visual-taxonomy/train.csv')
train_text.head()
# Out:
#    id     Category  len      attr_1 attr_2   attr_3   attr_4         attr_5  \
# 0   0  Men Tshirts    5     default  round  printed  default  short sleeves
# 1   1  Men Tshirts    5  multicolor   polo    solid    solid  short sleeves
# 2   2  Men Tshirts    5     default   polo    solid    solid  short sleeves
# 3   3  Men Tshirts    5  multicolor   polo    solid    solid  short sleeves
# 4   4  Men Tshirts    5  multicolor   polo    solid    solid  short sleeves
#
#   attr_6 attr_7 attr_8 attr_9 attr_10
# 0    NaN    NaN    NaN    NaN     NaN
# 1    NaN    NaN    NaN    NaN     NaN
# 2    NaN    NaN    NaN    NaN     NaN
# 3    NaN    NaN    NaN    NaN     NaN
# 4    NaN    NaN    NaN    NaN     NaN

# %%
train_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70213 entries, 0 to 70212
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        70213 non-null  int64
#  1   Category  70213 non-null  object
#  2   len       70213 non-null  int64
#  3   attr_1    51867 non-null  object
#  4   attr_2    55192 non-null  object
#  5   attr_3    54698 non-null  object
#  6   attr_4    59888 non-null  object
#  7   attr_5    56493 non-null  object
#  8   attr_6    38116 non-null  object
#  9   attr_7    41415 non-null  object
#  10  attr_8    37474 non-null  object
#  11  attr_9    33565 non-null  object
#  12  attr_10   24999 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 7.0+ MB

# %% [markdown]
# ## Importing the category attributes file

# %%
categort_attr=pd.read_parquet('/kaggle/input/c/visual-taxonomy/category_attributes.parquet', engine='pyarrow')
categort_attr
# Out:
#               Category  No_of_attribute  \
# 0          Men Tshirts                5
# 1               Sarees               10
# 2               Kurtis                9
# 3        Women Tshirts                8
# 4  Women Tops & Tunics               10
#
#                                       Attribute_list
# 0  [color, neck, pattern, print_or_pattern_type, ...
# 1  [blouse_pattern, border, border_width, color, ...
# 2  [color, fit_shape, length, occasion, ornamenta...
# 3  [color, fit_shape, length, pattern, print_or_p...
# 4  [color, fit_shape, length, neck_collar, ocassi...

# %%
category_len={'Men Tshirts':5,'Sarees':10,'Kurtis':9,'Women Tshirts':8,'Women Tops & Tunics':10}

# %% [markdown]
# ## Importing the test dataset

# %%
test_text=pd.read_csv('/kaggle/input/c/visual-taxonomy/test.csv')
test_text.head()
# Out:
#    id     Category
# 0   0  Men Tshirts
# 1   1  Men Tshirts
# 2   2  Men Tshirts
# 3   3  Men Tshirts
# 4   4  Men Tshirts

# %% [markdown]
# ### Import the npy training files for Mens Tshirt

# %%
train_mens=train_text[train_text['Category']=='Men Tshirts']
train_mens
# Out:
#         id     Category  len      attr_1 attr_2   attr_3   attr_4  \
# 0        0  Men Tshirts    5     default  round  printed  default
# 1        1  Men Tshirts    5  multicolor   polo    solid    solid
# 2        2  Men Tshirts    5     default   polo    solid    solid
# 3        3  Men Tshirts    5  multicolor   polo    solid    solid
# 4        4  Men Tshirts    5  multicolor   polo    solid    solid
# ...    ...          ...  ...         ...    ...      ...      ...
# 7262  7424  Men Tshirts    5         NaN    NaN  printed      NaN
# 7263  7425  Men Tshirts    5         NaN  round      NaN      NaN
# 7264  7426  Men Tshirts    5         NaN    NaN      NaN  default
# 7265  7429  Men Tshirts    5         NaN    NaN      NaN  default
# 7266  7430  Men Tshirts    5         NaN    NaN      NaN      NaN
#
#              attr_5 attr_6 attr_7 attr_8 attr_9 attr_10
# 0     short sleeves    NaN    NaN    NaN    NaN     NaN
# 1     short sleeves    NaN    NaN    NaN    NaN     NaN
# 2     short sleeves    NaN    NaN    NaN    NaN     NaN
# 3     short sleeves    NaN    NaN    NaN    NaN     NaN
# 4     short sleeves    NaN    NaN    NaN    NaN     NaN
# ...             ...    ...    ...    ...    ...     ...
# 7262            NaN    NaN    NaN    NaN    NaN     NaN
# 7263            NaN    NaN    NaN    NaN    NaN     NaN
# 7264  short sleeves    NaN    NaN    NaN    NaN     NaN
# 7265            NaN    NaN    NaN    NaN    NaN     NaN
# 7266  short sleeves    NaN    NaN    NaN    NaN     NaN
#
# [7267 rows x 13 columns]

# %%
ids=train_mens.loc[:,'id']
ids
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 7262    7424
# 7263    7425
# 7264    7426
# 7265    7429
# 7266    7430
# Name: id, Length: 7267, dtype: int64

# %%
train_mens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 0 to 7266
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7267 non-null   int64
#  1   Category  7267 non-null   object
#  2   len       7267 non-null   int64
#  3   attr_1    6010 non-null   object
#  4   attr_2    6144 non-null   object
#  5   attr_3    5791 non-null   object
#  6   attr_4    5949 non-null   object
#  7   attr_5    5977 non-null   object
#  8   attr_6    0 non-null      object
#  9   attr_7    0 non-null      object
#  10  attr_8    0 non-null      object
#  11  attr_9    0 non-null      object
#  12  attr_10   0 non-null      object
# dtypes: int64(2), object(11)
# memory usage: 794.8+ KB

# %%
import numpy as np
image_features=np.load('/kaggle/input/feature-npy-files/train_features_26k.npy') 

# Flatten the image features to (32, 768) for each sample
image_features = image_features.reshape((image_features.shape[0], -1))
image_features.shape
# Out:
# (26000, 768)

# %%
image_features
# Out:
# array([[ 0.20524895,  0.10485189, -0.25085878, ...,  0.00708892,
#          0.01810091,  0.10057463],
#        [ 0.2093038 ,  0.09222685, -0.24900681, ...,  0.00877148,
#          0.01552162,  0.10534279],
#        [ 0.21288495,  0.09265401, -0.24820913, ...,  0.00956801,
#          0.01688282,  0.10397972],
#        ...,
#        [ 0.20818265,  0.09877583, -0.25177553, ...,  0.0067789 ,
#          0.01961002,  0.10640552],
#        [ 0.20888638,  0.09654081, -0.25116318, ...,  0.00798714,
#          0.01885687,  0.1067618 ],
#        [ 0.20739684,  0.09681629, -0.24639948, ...,  0.01191875,
#          0.01177484,  0.09768106]], dtype=float32)

# %%
image_features=[image_features[i] for i in range(7431) if i in ids] #mens tshirt only
image_features=np.array(image_features)
image_features.shape
# Out:
# (7267, 768)

# %% [markdown]
# ## Training a combined model

# %%
# Checking for NaNs in the relevant columns
print(train_text[['attr_1', 'attr_2', 'attr_3', 'attr_4', 'attr_5', 'attr_6', 'attr_7', 'attr_8', 'attr_9', 'attr_10']].isna().sum())
# Out:
# attr_1     18346
# attr_2     15021
# attr_3     15515
# attr_4     10325
# attr_5     13720
# attr_6     32097
# attr_7     28798
# attr_8     32739
# attr_9     36648
# attr_10    45214
# dtype: int64

# %%
train_text = train_mens.fillna('dummy_value')

# %%
# Calculate number of unique classes for each attribute
num_attr_1_classes = train_text['attr_1'].nunique()
num_attr_2_classes = train_text['attr_2'].nunique()
num_attr_3_classes = train_text['attr_3'].nunique()
num_attr_4_classes = train_text['attr_4'].nunique()
num_attr_5_classes = train_text['attr_5'].nunique()
num_attr_6_classes = train_text['attr_6'].nunique()
num_attr_7_classes = train_text['attr_7'].nunique()
num_attr_8_classes = train_text['attr_8'].nunique()
num_attr_9_classes = train_text['attr_9'].nunique()
num_attr_10_classes = train_text['attr_10'].nunique()

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import numpy as np

# Function to encode labels and convert to correct dtype
def encode_labels(column):
    label_encoder = LabelEncoder()
    integer_encoded = label_encoder.fit_transform(train_text[column].fillna('dummy_value'))
    onehot_encoded = to_categorical(integer_encoded)
    onehot_encoded = onehot_encoded.astype('float32')  # Ensure the correct dtype
    return onehot_encoded, label_encoder

# Encode the labels for each attribute
attr_1_labels, encoder_attr_1 = encode_labels('attr_1')
attr_2_labels, encoder_attr_2 = encode_labels('attr_2')
attr_3_labels, encoder_attr_3 = encode_labels('attr_3')
attr_4_labels, encoder_attr_4 = encode_labels('attr_4')
attr_5_labels, encoder_attr_5 = encode_labels('attr_5')
attr_6_labels, encoder_attr_6 = encode_labels('attr_6')
attr_7_labels, encoder_attr_7 = encode_labels('attr_7')
attr_8_labels, encoder_attr_8 = encode_labels('attr_8')
attr_9_labels, encoder_attr_9 = encode_labels('attr_9')
attr_10_labels, encoder_attr_10 = encode_labels('attr_10')

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the 'Category' column
train_text['Category'] = label_encoder.fit_transform(train_text['Category'])

# %%
# Flatten the image features to (32, 768) for each sample
image_features = image_features.reshape((image_features.shape[0], -1))

# Redefine the model with correct input shape
from tensorflow.keras.layers import Input, Dense, Concatenate, Flatten
from tensorflow.keras.models import Model

# Input layers
image_input = Input(shape=(768,), name='image_input')  # For ViT features
tabular_input = Input(shape=(2,), name='tabular_input')  # For tabular data (2 features)

# Dense layers for image features
x1 = Dense(128, activation='relu')(image_input)

# Dense layers for tabular features
x2 = Dense(128, activation='relu')(tabular_input)

# Concatenate image and tabular inputs
x = Concatenate()([x1, x2])

# Further dense layers after concatenation
x = Dense(128, activation='relu')(x)

# Output layers for attributes
output_1 = Dense(num_attr_1_classes, activation='softmax', name='attr_1')(x)
output_2 = Dense(num_attr_2_classes, activation='softmax', name='attr_2')(x)
output_3 = Dense(num_attr_3_classes, activation='softmax', name='attr_3')(x)
output_4 = Dense(num_attr_4_classes, activation='softmax', name='attr_4')(x)
output_5 = Dense(num_attr_5_classes, activation='softmax', name='attr_5')(x)
output_6 = Dense(num_attr_6_classes, activation='softmax', name='attr_6')(x)
output_7 = Dense(num_attr_7_classes, activation='softmax', name='attr_7')(x)
output_8 = Dense(num_attr_8_classes, activation='softmax', name='attr_8')(x)
output_9 = Dense(num_attr_9_classes, activation='softmax', name='attr_9')(x)
output_10 = Dense(num_attr_10_classes, activation='softmax', name='attr_10')(x)

# Build the model
model = Model(inputs=[image_input, tabular_input], 
              outputs=[output_1, output_2, output_3, output_4, output_5, 
                       output_6, output_7, output_8, output_9, output_10])

# Compile the model
model.compile(optimizer='adam', 
              loss={'attr_1': 'categorical_crossentropy',
                    'attr_2': 'categorical_crossentropy',
                    'attr_3': 'categorical_crossentropy',
                    'attr_4': 'categorical_crossentropy',
                    'attr_5': 'categorical_crossentropy',
                    'attr_6': 'categorical_crossentropy',
                    'attr_7': 'categorical_crossentropy',
                    'attr_8': 'categorical_crossentropy',
                    'attr_9': 'categorical_crossentropy',
                    'attr_10': 'categorical_crossentropy'},
              metrics={'attr_1': 'accuracy',
                       'attr_2': 'accuracy',
                       'attr_3': 'accuracy',
                       'attr_4': 'accuracy',
                       'attr_5': 'accuracy',
                       'attr_6': 'accuracy',
                       'attr_7': 'accuracy',
                       'attr_8': 'accuracy',
                       'attr_9': 'accuracy',
                       'attr_10': 'accuracy'})  # Metrics for each output

# Train the model
history = model.fit([image_features, train_text.iloc[:len(image_features), :2].values], 
                    [attr_1_labels, attr_2_labels, attr_3_labels, 
                     attr_4_labels, attr_5_labels, attr_6_labels, 
                     attr_7_labels, attr_8_labels, attr_9_labels, 
                     attr_10_labels],
                    epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/keras/src/losses/losses.py:22: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2510 - attr_2_accuracy: 0.4676 - attr_3_accuracy: 0.4257 - attr_4_accuracy: 0.3776 - attr_5_accuracy: 0.7343 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 127.6456 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.0750 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 208.9573
# Epoch 2/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2453 - attr_2_accuracy: 0.4552 - attr_3_accuracy: 0.4318 - attr_4_accuracy: 0.3905 - attr_5_accuracy: 0.7827 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 39.8007 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.5406 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.0138 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 181.0110
# Epoch 3/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2862 - attr_2_accuracy: 0.4443 - attr_3_accuracy: 0.4290 - attr_4_accuracy: 0.4133 - attr_5_accuracy: 0.7881 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 31.4799 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.7008 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.5777 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 81.5058
# Epoch 4/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2810 - attr_2_accuracy: 0.4736 - attr_3_accuracy: 0.4559 - attr_4_accuracy: 0.4052 - attr_5_accuracy: 0.8048 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 23.1894 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.7015 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.0750 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 127.0054
# Epoch 5/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2925 - attr_2_accuracy: 0.4596 - attr_3_accuracy: 0.4559 - attr_4_accuracy: 0.4151 - attr_5_accuracy: 0.7961 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 21.8478 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0550 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 163.9132
# Epoch 6/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2769 - attr_2_accuracy: 0.4700 - attr_3_accuracy: 0.4416 - attr_4_accuracy: 0.4139 - attr_5_accuracy: 0.8033 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 21.8155 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.5777 - val_attr_4_accuracy: 0.6788 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 52.4338
# Epoch 7/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2785 - attr_2_accuracy: 0.4762 - attr_3_accuracy: 0.4274 - attr_4_accuracy: 0.4099 - attr_5_accuracy: 0.7802 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 20.1475 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0543 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.0750 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 121.4534
# Epoch 8/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2983 - attr_2_accuracy: 0.4706 - attr_3_accuracy: 0.4598 - attr_4_accuracy: 0.4489 - attr_5_accuracy: 0.8041 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 18.9580 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0908 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.0750 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 42.8156
# Epoch 9/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2705 - attr_2_accuracy: 0.4749 - attr_3_accuracy: 0.4449 - attr_4_accuracy: 0.4566 - attr_5_accuracy: 0.8153 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 15.5513 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.3961 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.0942 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 53.2366
# Epoch 10/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2924 - attr_2_accuracy: 0.5173 - attr_3_accuracy: 0.4836 - attr_4_accuracy: 0.4806 - attr_5_accuracy: 0.8277 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 11.8218 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.6039 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 70.0029
# Epoch 11/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2869 - attr_2_accuracy: 0.5276 - attr_3_accuracy: 0.4770 - attr_4_accuracy: 0.4733 - attr_5_accuracy: 0.8144 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 11.8534 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.7008 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.5777 - val_attr_4_accuracy: 0.0612 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 62.3283
# Epoch 12/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.2963 - attr_2_accuracy: 0.5567 - attr_3_accuracy: 0.5078 - attr_4_accuracy: 0.5036 - attr_5_accuracy: 0.8265 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 12.1087 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.7008 - val_attr_2_accuracy: 0.1472 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.0626 - val_attr_5_accuracy: 0.5846 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 26.4838
# Epoch 13/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3130 - attr_2_accuracy: 0.5194 - attr_3_accuracy: 0.5247 - attr_4_accuracy: 0.4933 - attr_5_accuracy: 0.8140 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 10.3290 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.7008 - val_attr_2_accuracy: 0.4106 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.6788 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 13.0288
# Epoch 14/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3165 - attr_2_accuracy: 0.5890 - attr_3_accuracy: 0.5443 - attr_4_accuracy: 0.5326 - attr_5_accuracy: 0.8239 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 8.8263 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0908 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 36.0720
# Epoch 15/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3321 - attr_2_accuracy: 0.5983 - attr_3_accuracy: 0.5684 - attr_4_accuracy: 0.5610 - attr_5_accuracy: 0.8457 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 7.6358 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.3453 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.5674 - val_attr_4_accuracy: 0.0757 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 25.6501
# Epoch 16/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3326 - attr_2_accuracy: 0.5987 - attr_3_accuracy: 0.5528 - attr_4_accuracy: 0.5416 - attr_5_accuracy: 0.8113 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 8.3743 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4175 - val_attr_3_accuracy: 0.1094 - val_attr_4_accuracy: 0.1719 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 22.3340
# Epoch 17/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3385 - attr_2_accuracy: 0.6295 - attr_3_accuracy: 0.6013 - attr_4_accuracy: 0.5837 - attr_5_accuracy: 0.8347 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 6.9641 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0880 - val_attr_2_accuracy: 0.5406 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.1754 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 41.8073
# Epoch 18/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3219 - attr_2_accuracy: 0.6287 - attr_3_accuracy: 0.5802 - attr_4_accuracy: 0.5918 - attr_5_accuracy: 0.8297 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 7.4890 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0550 - val_attr_2_accuracy: 0.4092 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.1678 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 21.2662
# Epoch 19/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3233 - attr_2_accuracy: 0.6613 - attr_3_accuracy: 0.5714 - attr_4_accuracy: 0.5988 - attr_5_accuracy: 0.8402 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 7.0307 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.0770 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.5426 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 14.8878
# Epoch 20/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3394 - attr_2_accuracy: 0.6653 - attr_3_accuracy: 0.6166 - attr_4_accuracy: 0.5940 - attr_5_accuracy: 0.8257 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 6.3620 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.3618 - val_attr_4_accuracy: 0.5433 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 16.5305
# Epoch 21/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3401 - attr_2_accuracy: 0.6727 - attr_3_accuracy: 0.5995 - attr_4_accuracy: 0.5983 - attr_5_accuracy: 0.8305 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 6.5648 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.6754 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 19.9476
# Epoch 22/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3549 - attr_2_accuracy: 0.6775 - attr_3_accuracy: 0.6216 - attr_4_accuracy: 0.6032 - attr_5_accuracy: 0.8420 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.9011 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.1836 - val_attr_2_accuracy: 0.4993 - val_attr_3_accuracy: 0.0557 - val_attr_4_accuracy: 0.1871 - val_attr_5_accuracy: 0.0165 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 17.7564
# Epoch 23/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3359 - attr_2_accuracy: 0.6784 - attr_3_accuracy: 0.6300 - attr_4_accuracy: 0.6187 - attr_5_accuracy: 0.8489 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 6.2248 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.5358 - val_attr_3_accuracy: 0.5777 - val_attr_4_accuracy: 0.4608 - val_attr_5_accuracy: 0.4340 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 10.4376
# Epoch 24/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3587 - attr_2_accuracy: 0.6764 - attr_3_accuracy: 0.6708 - attr_4_accuracy: 0.6120 - attr_5_accuracy: 0.8524 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.7785 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.3535 - val_attr_4_accuracy: 0.4684 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 29.1527
# Epoch 25/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3602 - attr_2_accuracy: 0.7232 - attr_3_accuracy: 0.6654 - attr_4_accuracy: 0.6169 - attr_5_accuracy: 0.8280 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.8938 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.6939 - val_attr_2_accuracy: 0.5261 - val_attr_3_accuracy: 0.3597 - val_attr_4_accuracy: 0.6788 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 12.6159
# Epoch 26/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3518 - attr_2_accuracy: 0.6819 - attr_3_accuracy: 0.6551 - attr_4_accuracy: 0.6179 - attr_5_accuracy: 0.8464 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.8570 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.6444 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 18.2279
# Epoch 27/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3660 - attr_2_accuracy: 0.7039 - attr_3_accuracy: 0.6376 - attr_4_accuracy: 0.6201 - attr_5_accuracy: 0.8414 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.4388 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0832 - val_attr_2_accuracy: 0.0468 - val_attr_3_accuracy: 0.2655 - val_attr_4_accuracy: 0.0853 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 17.6512
# Epoch 28/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3703 - attr_2_accuracy: 0.6886 - attr_3_accuracy: 0.6497 - attr_4_accuracy: 0.6245 - attr_5_accuracy: 0.8543 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.2971 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.6107 - val_attr_2_accuracy: 0.5406 - val_attr_3_accuracy: 0.3597 - val_attr_4_accuracy: 0.4656 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.7292
# Epoch 29/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3668 - attr_2_accuracy: 0.6952 - attr_3_accuracy: 0.6697 - attr_4_accuracy: 0.6207 - attr_5_accuracy: 0.8387 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.0845 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.4147 - val_attr_2_accuracy: 0.4161 - val_attr_3_accuracy: 0.1114 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.6025 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.6286
# Epoch 30/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3684 - attr_2_accuracy: 0.6975 - attr_3_accuracy: 0.6310 - attr_4_accuracy: 0.6236 - attr_5_accuracy: 0.8464 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 5.2982 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.5055 - val_attr_2_accuracy: 0.5227 - val_attr_3_accuracy: 0.3652 - val_attr_4_accuracy: 0.6664 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 6.1685
# Epoch 31/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3629 - attr_2_accuracy: 0.7664 - attr_3_accuracy: 0.6932 - attr_4_accuracy: 0.6695 - attr_5_accuracy: 0.8610 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.3033 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.6994 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.3597 - val_attr_4_accuracy: 0.1891 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 10.3550
# Epoch 32/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.4082 - attr_2_accuracy: 0.7380 - attr_3_accuracy: 0.7037 - attr_4_accuracy: 0.6743 - attr_5_accuracy: 0.8608 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.2047 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0928 - val_attr_2_accuracy: 0.2153 - val_attr_3_accuracy: 0.3480 - val_attr_4_accuracy: 0.1829 - val_attr_5_accuracy: 0.3858 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 9.1760
# Epoch 33/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3940 - attr_2_accuracy: 0.7375 - attr_3_accuracy: 0.7033 - attr_4_accuracy: 0.6675 - attr_5_accuracy: 0.8568 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.3410 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.4065 - val_attr_2_accuracy: 0.3569 - val_attr_3_accuracy: 0.0702 - val_attr_4_accuracy: 0.1431 - val_attr_5_accuracy: 0.5371 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 9.3307
# Epoch 34/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3942 - attr_2_accuracy: 0.7493 - attr_3_accuracy: 0.6728 - attr_4_accuracy: 0.6724 - attr_5_accuracy: 0.8488 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.3438 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.1912 - val_attr_3_accuracy: 0.2221 - val_attr_4_accuracy: 0.1169 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.7765
# Epoch 35/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3367 - attr_2_accuracy: 0.7147 - attr_3_accuracy: 0.6512 - attr_4_accuracy: 0.6373 - attr_5_accuracy: 0.8580 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.3815 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0736 - val_attr_2_accuracy: 0.0591 - val_attr_3_accuracy: 0.2985 - val_attr_4_accuracy: 0.1114 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 11.1270
# Epoch 36/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3542 - attr_2_accuracy: 0.7129 - attr_3_accuracy: 0.7036 - attr_4_accuracy: 0.6693 - attr_5_accuracy: 0.8720 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.2301 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0818 - val_attr_2_accuracy: 0.2448 - val_attr_3_accuracy: 0.1410 - val_attr_4_accuracy: 0.1066 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 10.6137
# Epoch 37/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3699 - attr_2_accuracy: 0.7408 - attr_3_accuracy: 0.7027 - attr_4_accuracy: 0.6626 - attr_5_accuracy: 0.8767 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.2159 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0736 - val_attr_2_accuracy: 0.4010 - val_attr_3_accuracy: 0.2916 - val_attr_4_accuracy: 0.1747 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 6.9828
# Epoch 38/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3570 - attr_2_accuracy: 0.7214 - attr_3_accuracy: 0.6802 - attr_4_accuracy: 0.6279 - attr_5_accuracy: 0.8730 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.7564 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.0487
# Epoch 39/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3389 - attr_2_accuracy: 0.6956 - attr_3_accuracy: 0.6058 - attr_4_accuracy: 0.5795 - attr_5_accuracy: 0.8812 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.4947 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.4106 - val_attr_3_accuracy: 0.3659 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.3260
# Epoch 40/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3524 - attr_2_accuracy: 0.7148 - attr_3_accuracy: 0.6683 - attr_4_accuracy: 0.5968 - attr_5_accuracy: 0.8693 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.3521 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.0426 - val_attr_3_accuracy: 0.0812 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 10.5895
# Epoch 41/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3510 - attr_2_accuracy: 0.6847 - attr_3_accuracy: 0.6401 - attr_4_accuracy: 0.5861 - attr_5_accuracy: 0.8744 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.4914 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.4140 - val_attr_3_accuracy: 0.3624 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.4849
# Epoch 42/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3559 - attr_2_accuracy: 0.7176 - attr_3_accuracy: 0.6792 - attr_4_accuracy: 0.6330 - attr_5_accuracy: 0.8829 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.2531 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.3948 - val_attr_3_accuracy: 0.3301 - val_attr_4_accuracy: 0.1802 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.8386
# Epoch 43/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3595 - attr_2_accuracy: 0.7602 - attr_3_accuracy: 0.7195 - attr_4_accuracy: 0.6581 - attr_5_accuracy: 0.8802 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.0904 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0777 - val_attr_2_accuracy: 0.3714 - val_attr_3_accuracy: 0.3150 - val_attr_4_accuracy: 0.1754 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.0591
# Epoch 44/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3780 - attr_2_accuracy: 0.7327 - attr_3_accuracy: 0.7005 - attr_4_accuracy: 0.6455 - attr_5_accuracy: 0.8713 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.1657 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4154 - val_attr_3_accuracy: 0.3652 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.7419
# Epoch 45/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3888 - attr_2_accuracy: 0.7718 - attr_3_accuracy: 0.7196 - attr_4_accuracy: 0.6790 - attr_5_accuracy: 0.8745 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 3.9766 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0757 - val_attr_2_accuracy: 0.1933 - val_attr_3_accuracy: 0.1657 - val_attr_4_accuracy: 0.1039 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 10.4792
# Epoch 46/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3846 - attr_2_accuracy: 0.7142 - attr_3_accuracy: 0.6793 - attr_4_accuracy: 0.6191 - attr_5_accuracy: 0.8744 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.1672 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0715 - val_attr_2_accuracy: 0.2442 - val_attr_3_accuracy: 0.2166 - val_attr_4_accuracy: 0.1259 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 9.7514
# Epoch 47/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3966 - attr_2_accuracy: 0.7478 - attr_3_accuracy: 0.7175 - attr_4_accuracy: 0.6569 - attr_5_accuracy: 0.8762 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.0345 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0763 - val_attr_2_accuracy: 0.4168 - val_attr_3_accuracy: 0.3666 - val_attr_4_accuracy: 0.1850 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 7.7889
# Epoch 48/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3851 - attr_2_accuracy: 0.7526 - attr_3_accuracy: 0.7149 - attr_4_accuracy: 0.6493 - attr_5_accuracy: 0.8747 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.1077 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0777 - val_attr_2_accuracy: 0.3528 - val_attr_3_accuracy: 0.3143 - val_attr_4_accuracy: 0.1747 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.4229
# Epoch 49/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3869 - attr_2_accuracy: 0.7363 - attr_3_accuracy: 0.7087 - attr_4_accuracy: 0.6484 - attr_5_accuracy: 0.8728 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.1202 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0770 - val_attr_2_accuracy: 0.4085 - val_attr_3_accuracy: 0.3604 - val_attr_4_accuracy: 0.1946 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 8.0587
# Epoch 50/50
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - attr_10_accuracy: 1.0000 - attr_1_accuracy: 0.3786 - attr_2_accuracy: 0.7360 - attr_3_accuracy: 0.6875 - attr_4_accuracy: 0.6294 - attr_5_accuracy: 0.8753 - attr_6_accuracy: 1.0000 - attr_7_accuracy: 1.0000 - attr_8_accuracy: 1.0000 - attr_9_accuracy: 1.0000 - loss: 4.1505 - val_attr_10_accuracy: 1.0000 - val_attr_1_accuracy: 0.0777 - val_attr_2_accuracy: 0.2751 - val_attr_3_accuracy: 0.2503 - val_attr_4_accuracy: 0.1424 - val_attr_5_accuracy: 0.3838 - val_attr_6_accuracy: 1.0000 - val_attr_7_accuracy: 1.0000 - val_attr_8_accuracy: 1.0000 - val_attr_9_accuracy: 1.0000 - val_loss: 10.0581

# %% [markdown]
# ## Test the model

# %%
test_text[test_text['Category']=='Men Tshirts']
# Out:
#         id     Category
# 0        0  Men Tshirts
# 1        1  Men Tshirts
# 2        2  Men Tshirts
# 3        3  Men Tshirts
# 4        4  Men Tshirts
# ...    ...          ...
# 3782  3782  Men Tshirts
# 3783  3783  Men Tshirts
# 3784  3784  Men Tshirts
# 3785  3785  Men Tshirts
# 3786  3786  Men Tshirts
#
# [3787 rows x 2 columns]

# %%
test_features=np.load('/kaggle/input/feature-npy-files/test_features_30500.npy') 
# Reshape the test_features to match the expected input shape
test_features = test_features.reshape(test_features.shape[0], -1)
test_features.shape
# Out:
# (30489, 768)

# %%
test_features=test_features[:3787] #men tshirts

# %%
test_features.shape
# Out:
# (3787, 768)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Encode categorical columns
categorical_columns = test_text.select_dtypes(include=['object']).columns
label_encoder = LabelEncoder()
for i in categorical_columns:
    test_text[i] = label_encoder.fit_transform(test_text[i])

# %%
predicted_values=len(test_features)

# Convert to numpy arrays
test_tabular_features = test_text[:predicted_values].values

# %%
print("Shape of test_tabular_features:", test_tabular_features.shape)
# Out:
# Shape of test_tabular_features: (3787, 2)

# %%
# Get predictions from the trained model
predictions = model.predict([test_features[:predicted_values], test_tabular_features])
# Out:
#  19/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /opt/conda/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (32, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# /opt/conda/lib/python3.10/site-packages/keras/src/ops/nn.py:545: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(

# %%
# Extract the class with the highest probability for each attribute prediction
predicted_labels = []
for i, prediction in enumerate(predictions):
    predicted_labels.append(np.argmax(prediction, axis=1))

# Display the predicted labels for each attribute
for i, label in enumerate(predicted_labels):
    print(f"Predicted Labels for Attribute {i+1}: {label}")
# Out:
# Predicted Labels for Attribute 1: [1 1 1 ... 3 3 3]
# Predicted Labels for Attribute 2: [2 2 2 ... 1 1 1]
# Predicted Labels for Attribute 3: [1 1 2 ... 2 2 2]
# Predicted Labels for Attribute 4: [0 0 0 ... 2 2 2]
# Predicted Labels for Attribute 5: [2 2 2 ... 2 2 2]
# Predicted Labels for Attribute 6: [0 0 0 ... 0 0 0]
# Predicted Labels for Attribute 7: [0 0 0 ... 0 0 0]
# Predicted Labels for Attribute 8: [0 0 0 ... 0 0 0]
# Predicted Labels for Attribute 9: [0 0 0 ... 0 0 0]
# Predicted Labels for Attribute 10: [0 0 0 ... 0 0 0]

# %%
import pandas as pd
import numpy as np

# Number of test samples
total_test_samples = 30205  # Total number of test rows
#predicted_samples = 4440    # Number of predicted samples

# Create a DataFrame with NaN for all rows initially
submission_df = pd.DataFrame(np.nan, index=range(total_test_samples), columns=['id','Category','len',
    'Attribute_1', 'Attribute_2', 'Attribute_3', 'Attribute_4', 'Attribute_5', 
    'Attribute_6', 'Attribute_7', 'Attribute_8', 'Attribute_9', 'Attribute_10'
])

# %%
test_text=pd.read_csv('/kaggle/input/c/visual-taxonomy/test.csv')
test_text.head()
# Out:
#    id     Category
# 0   0  Men Tshirts
# 1   1  Men Tshirts
# 2   2  Men Tshirts
# 3   3  Men Tshirts
# 4   4  Men Tshirts

# %%
submission_df.iloc[:30205,0] = test_text.iloc[:,0]
submission_df.iloc[:30205,1] = test_text.iloc[:,1]
# Out:
# /tmp/ipykernel_31/4028425247.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['Men Tshirts' 'Men Tshirts' 'Men Tshirts' ... 'Women Tops & Tunics'
#  'Women Tops & Tunics' 'Women Tops & Tunics']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:30205,1] = test_text.iloc[:,1]

# %%
submission_df.loc[:, 'len'] = submission_df['Category'].map(category_len)

# %%
# Reverse the encoding of predicted labels using LabelEncoder's inverse_transform
reversed_attr_1 = encoder_attr_1.inverse_transform(predicted_labels[0])  # For Attribute 1
reversed_attr_2 = encoder_attr_2.inverse_transform(predicted_labels[1])  # For Attribute 2
reversed_attr_3 = encoder_attr_3.inverse_transform(predicted_labels[2])  # For Attribute 3
reversed_attr_4 = encoder_attr_4.inverse_transform(predicted_labels[3])  # For Attribute 4
reversed_attr_5 = encoder_attr_5.inverse_transform(predicted_labels[4])  # For Attribute 5
reversed_attr_6 = encoder_attr_6.inverse_transform(predicted_labels[5])  # For Attribute 6
reversed_attr_7 = encoder_attr_7.inverse_transform(predicted_labels[6])  # For Attribute 7
reversed_attr_8 = encoder_attr_8.inverse_transform(predicted_labels[7])  # For Attribute 8
reversed_attr_9 = encoder_attr_9.inverse_transform(predicted_labels[8])  # For Attribute 9
reversed_attr_10 = encoder_attr_10.inverse_transform(predicted_labels[9])  # For Attribute 10

# %%
# Prepare the submission DataFrame
submission_df.iloc[:predicted_values, 3] = reversed_attr_1
submission_df.iloc[:predicted_values, 4] = reversed_attr_2
submission_df.iloc[:predicted_values, 5] = reversed_attr_3
submission_df.iloc[:predicted_values, 6] = reversed_attr_4
submission_df.iloc[:predicted_values, 7] = reversed_attr_5
submission_df.iloc[:predicted_values, 8] = reversed_attr_6
submission_df.iloc[:predicted_values, 9] = reversed_attr_7
submission_df.iloc[:predicted_values, 10] = reversed_attr_8
submission_df.iloc[:predicted_values, 11] = reversed_attr_9
submission_df.iloc[:predicted_values, 12] = reversed_attr_10

# Fill the remaining rows with NaN
submission_df.iloc[predicted_values:] = np.nan
# Out:
# /tmp/ipykernel_31/4084899079.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['default' 'default' 'default' ... 'multicolor' 'multicolor' 'multicolor']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 3] = reversed_attr_1
# /tmp/ipykernel_31/4084899079.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['round' 'round' 'round' ... 'polo' 'polo' 'polo']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 4] = reversed_attr_2
# /tmp/ipykernel_31/4084899079.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['printed' 'printed' 'solid' ... 'solid' 'solid' 'solid']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 5] = reversed_attr_3
# /tmp/ipykernel_31/4084899079.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['default' 'default' 'default' ... 'solid' 'solid' 'solid']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 6] = reversed_attr_4
# /tmp/ipykernel_31/4084899079.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['short sleeves' 'short sleeves' 'short sleeves' ... 'short sleeves'
#  'short sleeves' 'short sleeves']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 7] = reversed_attr_5
# /tmp/ipykernel_31/4084899079.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 8] = reversed_attr_6
# /tmp/ipykernel_31/4084899079.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 9] = reversed_attr_7
# /tmp/ipykernel_31/4084899079.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 10] = reversed_attr_8
# /tmp/ipykernel_31/4084899079.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 11] = reversed_attr_9
# /tmp/ipykernel_31/4084899079.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:predicted_values, 12] = reversed_attr_10

# %%
submission_df=submission_df.iloc[:30205,:]

# %%
submission_df
# Out:
#         id     Category  len Attribute_1  Attribute_2 Attribute_3 Attribute_4  \
# 0      0.0  Men Tshirts  5.0     default        round     printed     default
# 1      1.0  Men Tshirts  5.0     default        round     printed     default
# 2      2.0  Men Tshirts  5.0     default        round       solid     default
# 3      3.0  Men Tshirts  5.0  multicolor         polo       solid       solid
# 4      4.0  Men Tshirts  5.0  multicolor  dummy_value       solid       solid
# ...    ...          ...  ...         ...          ...         ...         ...
# 30200  NaN          NaN  NaN         NaN          NaN         NaN         NaN
# 30201  NaN          NaN  NaN         NaN          NaN         NaN         NaN
# 30202  NaN          NaN  NaN         NaN          NaN         NaN         NaN
# 30203  NaN          NaN  NaN         NaN          NaN         NaN         NaN
# 30204  NaN          NaN  NaN         NaN          NaN         NaN         NaN
#
#          Attribute_5  Attribute_6  Attribute_7  Attribute_8  Attribute_9  \
# 0      short sleeves  dummy_value  dummy_value  dummy_value  dummy_value
# 1      short sleeves  dummy_value  dummy_value  dummy_value  dummy_value
# 2      short sleeves  dummy_value  dummy_value  dummy_value  dummy_value
# 3      short sleeves  dummy_value  dummy_value  dummy_value  dummy_value
# 4      short sleeves  dummy_value  dummy_value  dummy_value  dummy_value
# ...              ...          ...          ...          ...          ...
# 30200            NaN          NaN          NaN          NaN          NaN
# 30201            NaN          NaN          NaN          NaN          NaN
# 30202            NaN          NaN          NaN          NaN          NaN
# 30203            NaN          NaN          NaN          NaN          NaN
# 30204            NaN          NaN          NaN          NaN          NaN
#
#       Attribute_10
# 0      dummy_value
# 1      dummy_value
# 2      dummy_value
# 3      dummy_value
# 4      dummy_value
# ...            ...
# 30200          NaN
# 30201          NaN
# 30202          NaN
# 30203          NaN
# 30204          NaN
#
# [30205 rows x 13 columns]

# %%
submission_df.fillna('nu', inplace=True)
# Out:
# /tmp/ipykernel_31/2203038571.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nu' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.fillna('nu', inplace=True)

# %%
submission_df.iloc[:30205,0] = test_text.iloc[:,0]
submission_df.iloc[:30205,1] = test_text.iloc[:,1]

# %%
# Rename columns
submission_df.rename(columns={
    'Attribute_1': 'attr_1',
    'Attribute_2': 'attr_2',
    'Attribute_3': 'attr_3',
    'Attribute_4': 'attr_4',
    'Attribute_5': 'attr_5',
    'Attribute_6': 'attr_6',
    'Attribute_7': 'attr_7',
    'Attribute_8': 'attr_8',
    'Attribute_9': 'attr_9',
    'Attribute_10': 'attr_10',
}, inplace=True)

# %%
submission_df
# Out:
#           id             Category  len      attr_1       attr_2   attr_3  \
# 0          0          Men Tshirts  5.0     default        round  printed
# 1          1          Men Tshirts  5.0     default        round  printed
# 2          2          Men Tshirts  5.0     default        round    solid
# 3          3          Men Tshirts  5.0  multicolor         polo    solid
# 4          4          Men Tshirts  5.0  multicolor  dummy_value    solid
# ...      ...                  ...  ...         ...          ...      ...
# 30200  30484  Women Tops & Tunics   nu          nu           nu       nu
# 30201  30485  Women Tops & Tunics   nu          nu           nu       nu
# 30202  30486  Women Tops & Tunics   nu          nu           nu       nu
# 30203  30487  Women Tops & Tunics   nu          nu           nu       nu
# 30204  30488  Women Tops & Tunics   nu          nu           nu       nu
#
#         attr_4         attr_5       attr_6       attr_7       attr_8  \
# 0      default  short sleeves  dummy_value  dummy_value  dummy_value
# 1      default  short sleeves  dummy_value  dummy_value  dummy_value
# 2      default  short sleeves  dummy_value  dummy_value  dummy_value
# 3        solid  short sleeves  dummy_value  dummy_value  dummy_value
# 4        solid  short sleeves  dummy_value  dummy_value  dummy_value
# ...        ...            ...          ...          ...          ...
# 30200       nu             nu           nu           nu           nu
# 30201       nu             nu           nu           nu           nu
# 30202       nu             nu           nu           nu           nu
# 30203       nu             nu           nu           nu           nu
# 30204       nu             nu           nu           nu           nu
#
#             attr_9      attr_10
# 0      dummy_value  dummy_value
# 1      dummy_value  dummy_value
# 2      dummy_value  dummy_value
# 3      dummy_value  dummy_value
# 4      dummy_value  dummy_value
# ...            ...          ...
# 30200           nu           nu
# 30201           nu           nu
# 30202           nu           nu
# 30203           nu           nu
# 30204           nu           nu
#
# [30205 rows x 13 columns]

# %%
# Save the DataFrame to a CSV file
submission_file = 'submission_MEN_TSHIRTS.csv'
submission_df.to_csv(submission_file, index=False)

print("Submission file created successfully!")
# Out:
# Submission file created successfully!
