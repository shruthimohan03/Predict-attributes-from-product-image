# %%
'''# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session'''
# Out:
# '# This Python 3 environment comes with many helpful analytics libraries installed\n# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python\n# For example, here\'s several helpful packages to load\n\nimport numpy as np # linear algebra\nimport pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)\n\n# Input data files are available in the read-only "../input/" directory\n# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory\n\nimport os\nfor dirname, _, filenames in os.walk(\'/kaggle/input\'):\n    for filename in filenames:\n        print(os.path.join(dirname, filename))\n\n# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" \n# You can also write temporary files to /kaggle/temp/, but they won\'t be saved outside of the current session'

# %% [markdown]
# ## Importing the training text dataset

# %%
import pandas as pd
train_text=pd.read_csv('/kaggle/input/visual-taxonomy/train.csv')
train_text.head()
# Out:
#    id     Category  len      attr_1 attr_2   attr_3   attr_4         attr_5  \
# 0   0  Men Tshirts    5     default  round  printed  default  short sleeves
# 1   1  Men Tshirts    5  multicolor   polo    solid    solid  short sleeves
# 2   2  Men Tshirts    5     default   polo    solid    solid  short sleeves
# 3   3  Men Tshirts    5  multicolor   polo    solid    solid  short sleeves
# 4   4  Men Tshirts    5  multicolor   polo    solid    solid  short sleeves
#
#   attr_6 attr_7 attr_8 attr_9 attr_10
# 0    NaN    NaN    NaN    NaN     NaN
# 1    NaN    NaN    NaN    NaN     NaN
# 2    NaN    NaN    NaN    NaN     NaN
# 3    NaN    NaN    NaN    NaN     NaN
# 4    NaN    NaN    NaN    NaN     NaN

# %%
train_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70213 entries, 0 to 70212
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        70213 non-null  int64
#  1   Category  70213 non-null  object
#  2   len       70213 non-null  int64
#  3   attr_1    51867 non-null  object
#  4   attr_2    55192 non-null  object
#  5   attr_3    54698 non-null  object
#  6   attr_4    59888 non-null  object
#  7   attr_5    56493 non-null  object
#  8   attr_6    38116 non-null  object
#  9   attr_7    41415 non-null  object
#  10  attr_8    37474 non-null  object
#  11  attr_9    33565 non-null  object
#  12  attr_10   24999 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 7.0+ MB

# %% [markdown]
# ## Importing the category attributes file

# %%
categort_attr=pd.read_parquet('/kaggle/input/visual-taxonomy/category_attributes.parquet', engine='pyarrow')
categort_attr
# Out:
#               Category  No_of_attribute  \
# 0          Men Tshirts                5
# 1               Sarees               10
# 2               Kurtis                9
# 3        Women Tshirts                8
# 4  Women Tops & Tunics               10
#
#                                       Attribute_list
# 0  [color, neck, pattern, print_or_pattern_type, ...
# 1  [blouse_pattern, border, border_width, color, ...
# 2  [color, fit_shape, length, occasion, ornamenta...
# 3  [color, fit_shape, length, pattern, print_or_p...
# 4  [color, fit_shape, length, neck_collar, ocassi...

# %%
category_len={'Men Tshirts':5,'Sarees':10,'Kurtis':9,'Women Tshirts':8,'Women Tops & Tunics':10}

# %% [markdown]
# ## Importing the test dataset

# %%
test_text=pd.read_csv('/kaggle/input/visual-taxonomy/test.csv')
test_text.head()
# Out:
#    id     Category
# 0   0  Men Tshirts
# 1   1  Men Tshirts
# 2   2  Men Tshirts
# 3   3  Men Tshirts
# 4   4  Men Tshirts

# %% [markdown]
# ### Import the npy training files for Sarees

# %%
train_sarees=train_text[train_text['Category']=='Sarees']
train_sarees
# Out:
#           id Category  len         attr_1         attr_2        attr_3  \
# 7267    7432   Sarees   10  same as saree   woven design  small border
# 7268    7433   Sarees   10    dummy_value           zari  small border
# 7269    7434   Sarees   10    dummy_value           zari  small border
# 7270    7435   Sarees   10  same as saree   woven design    big border
# 7271    7436   Sarees   10          solid      no border   dummy_value
# ...      ...      ...  ...            ...            ...           ...
# 25608  25773   Sarees   10    dummy_value           zari  small border
# 25609  25774   Sarees   10    dummy_value      no border     no border
# 25610  25775   Sarees   10    dummy_value           zari  small border
# 25611  25776   Sarees   10    dummy_value  temple border  small border
# 25612  25777   Sarees   10  same as saree   woven design    big border
#
#             attr_4       attr_5       attr_6         attr_7       attr_8  \
# 7267    multicolor        party     jacquard   woven design   zari woven
# 7268         cream  traditional  dummy_value    dummy_value   zari woven
# 7269         white        party  dummy_value    dummy_value   zari woven
# 7270       default  traditional  dummy_value  same as saree   zari woven
# 7271   dummy_value        daily  dummy_value    dummy_value  dummy_value
# ...            ...          ...          ...            ...          ...
# 25608        cream        party  dummy_value    dummy_value   zari woven
# 25609      default        party  dummy_value     zari woven   zari woven
# 25610        cream        party  dummy_value    dummy_value   zari woven
# 25611        cream        party  dummy_value    dummy_value   zari woven
# 25612   multicolor        party     jacquard   woven design   zari woven
#
#              attr_9 attr_10
# 7267       applique      no
# 7268       elephant      no
# 7269         floral      no
# 7270   ethnic motif      no
# 7271    dummy_value     yes
# ...             ...     ...
# 25608       peacock      no
# 25609       default      no
# 25610       peacock      no
# 25611       peacock      no
# 25612   dummy_value      no
#
# [18346 rows x 13 columns]

# %%
ids=train_sarees.loc[:,'id']
ids
# Out:
# 7267      7432
# 7268      7433
# 7269      7434
# 7270      7435
# 7271      7436
#          ...
# 25608    25773
# 25609    25774
# 25610    25775
# 25611    25776
# 25612    25777
# Name: id, Length: 18346, dtype: int64

# %%
train_sarees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18346 entries, 7267 to 25612
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        18346 non-null  int64
#  1   Category  18346 non-null  object
#  2   len       18346 non-null  int64
#  3   attr_1    7885 non-null   object
#  4   attr_2    17679 non-null  object
#  5   attr_3    15861 non-null  object
#  6   attr_4    17896 non-null  object
#  7   attr_5    17649 non-null  object
#  8   attr_6    5010 non-null   object
#  9   attr_7    8896 non-null   object
#  10  attr_8    16465 non-null  object
#  11  attr_9    14303 non-null  object
#  12  attr_10   17818 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 2.0+ MB

# %%
import numpy as np
image_features=np.load('/kaggle/input/feature-npy-files/train_features_26k.npy') 

# Flatten the image features to (32, 768) for each sample
image_features = image_features.reshape((image_features.shape[0], -1))
image_features.shape
# Out:
# (26000, 768)

# %%
image_features=[image_features[i] for i in ids] #mens tshirt only
image_features=np.array(image_features)
image_features.shape
# Out:
# (18346, 768)

# %% [markdown]
# ## Training a combined model

# %%
# Checking for NaNs in the relevant columns
print(train_text[['attr_1', 'attr_2', 'attr_3', 'attr_4', 'attr_5', 'attr_6', 'attr_7', 'attr_8', 'attr_9', 'attr_10']].isna().sum())
# Out:
# attr_1     0
# attr_2     0
# attr_3     0
# attr_4     0
# attr_5     0
# attr_6     0
# attr_7     0
# attr_8     0
# attr_9     0
# attr_10    0
# dtype: int64

# %%
train_text = train_sarees.fillna('dummy_value')

# %%
# Calculate number of unique classes for each attribute
num_attr_1_classes = train_text['attr_1'].nunique()
num_attr_2_classes = train_text['attr_2'].nunique()
num_attr_3_classes = train_text['attr_3'].nunique()
num_attr_4_classes = train_text['attr_4'].nunique()
num_attr_5_classes = train_text['attr_5'].nunique()
num_attr_6_classes = train_text['attr_6'].nunique()
num_attr_7_classes = train_text['attr_7'].nunique()
num_attr_8_classes = train_text['attr_8'].nunique()
num_attr_9_classes = train_text['attr_9'].nunique()
num_attr_10_classes = train_text['attr_10'].nunique()

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import numpy as np

# Function to encode labels and convert to correct dtype
def encode_labels(column):
    label_encoder = LabelEncoder()
    integer_encoded = label_encoder.fit_transform(train_text[column].fillna('dummy_value'))
    onehot_encoded = to_categorical(integer_encoded)
    onehot_encoded = onehot_encoded.astype('float32')  # Ensure the correct dtype
    return onehot_encoded, label_encoder

# Encode the labels for each attribute
attr_1_labels, encoder_attr_1 = encode_labels('attr_1')
attr_2_labels, encoder_attr_2 = encode_labels('attr_2')
attr_3_labels, encoder_attr_3 = encode_labels('attr_3')
attr_4_labels, encoder_attr_4 = encode_labels('attr_4')
attr_5_labels, encoder_attr_5 = encode_labels('attr_5')
attr_6_labels, encoder_attr_6 = encode_labels('attr_6')
attr_7_labels, encoder_attr_7 = encode_labels('attr_7')
attr_8_labels, encoder_attr_8 = encode_labels('attr_8')
attr_9_labels, encoder_attr_9 = encode_labels('attr_9')
attr_10_labels, encoder_attr_10 = encode_labels('attr_10')

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the 'Category' column
train_text['Category'] = label_encoder.fit_transform(train_text['Category'])

# %%
# Flatten the image features to (32, 768) for each sample
image_features = image_features.reshape((image_features.shape[0], -1))

# Redefine the model with correct input shape
from tensorflow.keras.layers import Input, Dense, Concatenate, Flatten
from tensorflow.keras.models import Model

# Input layers
image_input = Input(shape=(768,), name='image_input')  # For ViT features
tabular_input = Input(shape=(2,), name='tabular_input')  # For tabular data (2 features)

# Dense layers for image features
x1 = Dense(128, activation='relu')(image_input)

# Dense layers for tabular features
x2 = Dense(128, activation='relu')(tabular_input)

# Concatenate image and tabular inputs
x = Concatenate()([x1, x2])

# Further dense layers after concatenation
x = Dense(128, activation='relu')(x)

# Output layers for attributes
output_1 = Dense(num_attr_1_classes, activation='softmax', name='attr_1')(x)
output_2 = Dense(num_attr_2_classes, activation='softmax', name='attr_2')(x)
output_3 = Dense(num_attr_3_classes, activation='softmax', name='attr_3')(x)
output_4 = Dense(num_attr_4_classes, activation='softmax', name='attr_4')(x)
output_5 = Dense(num_attr_5_classes, activation='softmax', name='attr_5')(x)
output_6 = Dense(num_attr_6_classes, activation='softmax', name='attr_6')(x)
output_7 = Dense(num_attr_7_classes, activation='softmax', name='attr_7')(x)
output_8 = Dense(num_attr_8_classes, activation='softmax', name='attr_8')(x)
output_9 = Dense(num_attr_9_classes, activation='softmax', name='attr_9')(x)
output_10 = Dense(num_attr_10_classes, activation='softmax', name='attr_10')(x)

# Build the model
model = Model(inputs=[image_input, tabular_input], 
              outputs=[output_1, output_2, output_3, output_4, output_5, 
                       output_6, output_7, output_8, output_9, output_10])

# Compile the model
model.compile(optimizer='adam', 
              loss={'attr_1': 'categorical_crossentropy',
                    'attr_2': 'categorical_crossentropy',
                    'attr_3': 'categorical_crossentropy',
                    'attr_4': 'categorical_crossentropy',
                    'attr_5': 'categorical_crossentropy',
                    'attr_6': 'categorical_crossentropy',
                    'attr_7': 'categorical_crossentropy',
                    'attr_8': 'categorical_crossentropy',
                    'attr_9': 'categorical_crossentropy',
                    'attr_10': 'categorical_crossentropy'},
              metrics={'attr_1': 'accuracy',
                       'attr_2': 'accuracy',
                       'attr_3': 'accuracy',
                       'attr_4': 'accuracy',
                       'attr_5': 'accuracy',
                       'attr_6': 'accuracy',
                       'attr_7': 'accuracy',
                       'attr_8': 'accuracy',
                       'attr_9': 'accuracy',
                       'attr_10': 'accuracy'})  # Metrics for each output

# Train the model
history = model.fit([image_features, train_text.iloc[:, :2].values], 
                    [attr_1_labels, attr_2_labels, attr_3_labels, 
                     attr_4_labels, attr_5_labels, attr_6_labels, 
                     attr_7_labels, attr_8_labels, attr_9_labels, 
                     attr_10_labels],
                    epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - attr_10_accuracy: 0.6882 - attr_1_accuracy: 0.4038 - attr_2_accuracy: 0.3456 - attr_3_accuracy: 0.3745 - attr_4_accuracy: 0.2171 - attr_5_accuracy: 0.3904 - attr_6_accuracy: 0.5770 - attr_7_accuracy: 0.3351 - attr_8_accuracy: 0.5311 - attr_9_accuracy: 0.1527 - loss: 829.0798 - val_attr_10_accuracy: 0.8076 - val_attr_1_accuracy: 0.5747 - val_attr_2_accuracy: 0.3365 - val_attr_3_accuracy: 0.5349 - val_attr_4_accuracy: 0.2213 - val_attr_5_accuracy: 0.2790 - val_attr_6_accuracy: 0.2302 - val_attr_7_accuracy: 0.5248 - val_attr_8_accuracy: 0.0455 - val_attr_9_accuracy: 0.1747 - val_loss: 228.0683
# Epoch 2/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - attr_10_accuracy: 0.6757 - attr_1_accuracy: 0.4232 - attr_2_accuracy: 0.3331 - attr_3_accuracy: 0.3923 - attr_4_accuracy: 0.2188 - attr_5_accuracy: 0.3832 - attr_6_accuracy: 0.5816 - attr_7_accuracy: 0.3436 - attr_8_accuracy: 0.5438 - attr_9_accuracy: 0.1408 - loss: 128.4010 - val_attr_10_accuracy: 0.8076 - val_attr_1_accuracy: 0.2847 - val_attr_2_accuracy: 0.4768 - val_attr_3_accuracy: 0.5349 - val_attr_4_accuracy: 0.2602 - val_attr_5_accuracy: 0.5706 - val_attr_6_accuracy: 0.7289 - val_attr_7_accuracy: 0.5248 - val_attr_8_accuracy: 0.7482 - val_attr_9_accuracy: 0.1368 - val_loss: 135.4461
# Epoch 3/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - attr_10_accuracy: 0.6868 - attr_1_accuracy: 0.4354 - attr_2_accuracy: 0.3397 - attr_3_accuracy: 0.3993 - attr_4_accuracy: 0.2152 - attr_5_accuracy: 0.4155 - attr_6_accuracy: 0.5787 - attr_7_accuracy: 0.3363 - attr_8_accuracy: 0.5852 - attr_9_accuracy: 0.1504 - loss: 70.6207 - val_attr_10_accuracy: 0.8076 - val_attr_1_accuracy: 0.5747 - val_attr_2_accuracy: 0.4768 - val_attr_3_accuracy: 0.5349 - val_attr_4_accuracy: 0.2602 - val_attr_5_accuracy: 0.5706 - val_attr_6_accuracy: 0.7289 - val_attr_7_accuracy: 0.5248 - val_attr_8_accuracy: 0.7482 - val_attr_9_accuracy: 0.1447 - val_loss: 15.5250
# Epoch 4/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - attr_10_accuracy: 0.8111 - attr_1_accuracy: 0.5702 - attr_2_accuracy: 0.4672 - attr_3_accuracy: 0.5118 - attr_4_accuracy: 0.2668 - attr_5_accuracy: 0.5645 - attr_6_accuracy: 0.7294 - attr_7_accuracy: 0.5142 - attr_8_accuracy: 0.7345 - attr_9_accuracy: 0.1784 - loss: 15.0160 - val_attr_10_accuracy: 0.8076 - val_attr_1_accuracy: 0.5747 - val_attr_2_accuracy: 0.4768 - val_attr_3_accuracy: 0.5349 - val_attr_4_accuracy: 0.2747 - val_attr_5_accuracy: 0.5706 - val_attr_6_accuracy: 0.7289 - val_attr_7_accuracy: 0.5248 - val_attr_8_accuracy: 0.7482 - val_attr_9_accuracy: 0.2163 - val_loss: 13.7098
# Epoch 5/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - attr_10_accuracy: 0.8067 - attr_1_accuracy: 0.5730 - attr_2_accuracy: 0.4586 - attr_3_accuracy: 0.5076 - attr_4_accuracy: 0.2834 - attr_5_accuracy: 0.5631 - attr_6_accuracy: 0.7294 - attr_7_accuracy: 0.5134 - attr_8_accuracy: 0.7327 - attr_9_accuracy: 0.2258 - loss: 13.4917 - val_attr_10_accuracy: 0.8076 - val_attr_1_accuracy: 0.5747 - val_attr_2_accuracy: 0.4768 - val_attr_3_accuracy: 0.5349 - val_attr_4_accuracy: 0.2747 - val_attr_5_accuracy: 0.5706 - val_attr_6_accuracy: 0.7289 - val_attr_7_accuracy: 0.5248 - val_attr_8_accuracy: 0.7482 - val_attr_9_accuracy: 0.2163 - val_loss: 12.7485
# Epoch 6/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - attr_10_accuracy: 0.
━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - attr_10_accuracy: 0.8133 - attr_1_accuracy: 0.5697 - attr_2_accuracy: 0.4708 - attr_3_accuracy: 0.5089 - attr_4_accuracy: 0.2802 - attr_5_accuracy: 0.5638 - attr_6_accuracy: 0.7312 - attr_7_accuracy: 0.5190 - attr_8_accuracy: 0.7374 - attr_9_accuracy: 0.2224 - loss: 11.8573 - val_attr_10_accuracy: 0.8076 - val_attr_1_accuracy: 0.5747 - val_attr_2_accuracy: 0.4768 - val_attr_3_accuracy: 0.5349 - val_attr_4_accuracy: 0.2747 - val_attr_5_accuracy: 0.5706 - val_attr_6_accuracy: 0.7289 - val_attr_7_accuracy: 0.5248 - val_attr_8_accuracy: 0.7482 - val_attr_9_accuracy: 0.2163 - val_loss: 11.7676

# %% [markdown]
# ## Test the model

# %%
test_sarees=test_text[test_text['Category']=='Sarees']
test_sarees
# Out:
#           id Category
# 3787    3787   Sarees
# 3788    3788   Sarees
# 3789    3789   Sarees
# 3790    3790   Sarees
# 3791    3791   Sarees
# ...      ...      ...
# 10884  11150   Sarees
# 10885  11151   Sarees
# 10886  11152   Sarees
# 10887  11153   Sarees
# 10888  11154   Sarees
#
# [7102 rows x 2 columns]

# %%
test_ids=test_sarees['id']
test_ids
# Out:
# 3787      3787
# 3788      3788
# 3789      3789
# 3790      3790
# 3791      3791
#          ...
# 10884    11150
# 10885    11151
# 10886    11152
# 10887    11153
# 10888    11154
# Name: id, Length: 7102, dtype: int64

# %%
test_features=np.load('/kaggle/input/feature-npy-files/test_features_30500.npy') 
# Reshape the test_features to match the expected input shape
test_features = test_features.reshape(test_features.shape[0], -1)
test_features.shape
# Out:
# (30489, 768)

# %%
test_features=[test_features[i] for i in test_ids] #sarees

predicted_row1=3787
predicted_row2=10889

# %%
test_features=np.array(test_features)
test_features.shape
# Out:
# (7102, 768)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Encode categorical columns
categorical_columns = test_text.select_dtypes(include=['object']).columns
label_encoder = LabelEncoder()
for i in categorical_columns:
    test_sarees[i] = label_encoder.fit_transform(test_sarees[i])
# Out:
# /tmp/ipykernel_30/3449726849.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_sarees[i] = label_encoder.fit_transform(test_sarees[i])

# %%
# Convert to numpy arrays
test_tabular_features = test_sarees.values

# %%
print("Shape of test_tabular_features:", test_tabular_features.shape)
# Out:
# Shape of test_tabular_features: (7102, 2)

# %%
# Get predictions from the trained model
predictions = model.predict([test_features, test_tabular_features])
# Out:
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Extract the class with the highest probability for each attribute prediction
predicted_labels = []
for i, prediction in enumerate(predictions):
    predicted_labels.append(np.argmax(prediction, axis=1))

# Display the predicted labels for each attribute
for i, label in enumerate(predicted_labels):
    print(f"Predicted Labels for Attribute {i+1}: {label}")
# Out:
# Predicted Labels for Attribute 1: [1 1 1 ... 1 1 1]
# Predicted Labels for Attribute 2: [6 6 6 ... 6 6 6]
# Predicted Labels for Attribute 3: [3 3 3 ... 3 3 3]
# Predicted Labels for Attribute 4: [4 4 4 ... 4 4 4]
# Predicted Labels for Attribute 5: [2 2 2 ... 2 2 2]
# Predicted Labels for Attribute 6: [1 1 1 ... 1 1 1]
# Predicted Labels for Attribute 7: [1 1 1 ... 1 1 1]
# Predicted Labels for Attribute 8: [5 5 5 ... 5 5 5]
# Predicted Labels for Attribute 9: [4 4 4 ... 4 4 4]
# Predicted Labels for Attribute 10: [1 1 1 ... 1 1 1]

# %%
import pandas as pd
import numpy as np

# Number of test samples
total_test_samples = 30205  # Total number of test rows
#predicted_samples = 4440    # Number of predicted samples

# Create a DataFrame with NaN for all rows initially
submission_df = pd.DataFrame(np.nan, index=range(total_test_samples), columns=['id','Category','len',
    'Attribute_1', 'Attribute_2', 'Attribute_3', 'Attribute_4', 'Attribute_5', 
    'Attribute_6', 'Attribute_7', 'Attribute_8', 'Attribute_9', 'Attribute_10'
])

# %%
test_text=pd.read_csv('/kaggle/input/visual-taxonomy/test.csv')
test_text.head()
# Out:
#    id     Category
# 0   0  Men Tshirts
# 1   1  Men Tshirts
# 2   2  Men Tshirts
# 3   3  Men Tshirts
# 4   4  Men Tshirts

# %%
submission_df.iloc[:30205,0] = test_text.iloc[:,0]
submission_df.iloc[:30205,1] = test_text.iloc[:,1]
# Out:
# /tmp/ipykernel_30/4028425247.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['Men Tshirts' 'Men Tshirts' 'Men Tshirts' ... 'Women Tops & Tunics'
#  'Women Tops & Tunics' 'Women Tops & Tunics']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[:30205,1] = test_text.iloc[:,1]

# %%
submission_df.loc[:, 'len'] = submission_df['Category'].map(category_len)

# %%
# Reverse the encoding of predicted labels using LabelEncoder's inverse_transform
reversed_attr_1 = encoder_attr_1.inverse_transform(predicted_labels[0])  # For Attribute 1
reversed_attr_2 = encoder_attr_2.inverse_transform(predicted_labels[1])  # For Attribute 2
reversed_attr_3 = encoder_attr_3.inverse_transform(predicted_labels[2])  # For Attribute 3
reversed_attr_4 = encoder_attr_4.inverse_transform(predicted_labels[3])  # For Attribute 4
reversed_attr_5 = encoder_attr_5.inverse_transform(predicted_labels[4])  # For Attribute 5
reversed_attr_6 = encoder_attr_6.inverse_transform(predicted_labels[5])  # For Attribute 6
reversed_attr_7 = encoder_attr_7.inverse_transform(predicted_labels[6])  # For Attribute 7
reversed_attr_8 = encoder_attr_8.inverse_transform(predicted_labels[7])  # For Attribute 8
reversed_attr_9 = encoder_attr_9.inverse_transform(predicted_labels[8])  # For Attribute 9
reversed_attr_10 = encoder_attr_10.inverse_transform(predicted_labels[9])  # For Attribute 10

# %%
# Prepare the submission DataFrame
submission_df.iloc[predicted_row1:predicted_row2, 3] = reversed_attr_1
submission_df.iloc[predicted_row1:predicted_row2, 4] = reversed_attr_2
submission_df.iloc[predicted_row1:predicted_row2, 5] = reversed_attr_3
submission_df.iloc[predicted_row1:predicted_row2, 6] = reversed_attr_4
submission_df.iloc[predicted_row1:predicted_row2, 7] = reversed_attr_5
submission_df.iloc[predicted_row1:predicted_row2, 8] = reversed_attr_6
submission_df.iloc[predicted_row1:predicted_row2, 9] = reversed_attr_7
submission_df.iloc[predicted_row1:predicted_row2, 10] = reversed_attr_8
submission_df.iloc[predicted_row1:predicted_row2, 11] = reversed_attr_9
submission_df.iloc[predicted_row1:predicted_row2, 12] = reversed_attr_10

# Fill the remaining rows with NaN
submission_df.iloc[:predicted_row1]=np.nan
submission_df.iloc[predicted_row2:] = np.nan
# Out:
# /tmp/ipykernel_30/3064140982.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[predicted_row1:predicted_row2, 3] = reversed_attr_1
# /tmp/ipykernel_30/3064140982.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['zari' 'zari' 'zari' ... 'zari' 'zari' 'zari']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[predicted_row1:predicted_row2, 4] = reversed_attr_2
# /tmp/ipykernel_30/3064140982.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['small border' 'small border' 'small border' ... 'small border'
#  'small border' 'small border']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[predicted_row1:predicted_row2, 5] = reversed_attr_3
# /tmp/ipykernel_30/3064140982.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['multicolor' 'multicolor' 'multicolor' ... 'multicolor' 'multicolor'
#  'multicolor']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[predicted_row1:predicted_row2, 6] = reversed_attr_4
# /tmp/ipykernel_30/3064140982.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['party' 'party' 'party' ... 'party' 'party' 'party']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[predicted_row1:predicted_row2, 7] = reversed_attr_5
# /tmp/ipykernel_30/3064140982.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[predicted_row1:predicted_row2, 8] = reversed_attr_6
# /tmp/ipykernel_30/3064140982.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[predicted_row1:predicted_row2, 9] = reversed_attr_7
# /tmp/ipykernel_30/3064140982.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['zari woven' 'zari woven' 'zari woven' ... 'zari woven' 'zari woven'
#  'zari woven']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[predicted_row1:predicted_row2, 10] = reversed_attr_8
# /tmp/ipykernel_30/3064140982.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['dummy_value' 'dummy_value' 'dummy_value' ... 'dummy_value' 'dummy_value'
#  'dummy_value']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[predicted_row1:predicted_row2, 11] = reversed_attr_9
# /tmp/ipykernel_30/3064140982.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['no' 'no' 'no' ... 'no' 'no' 'no']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.iloc[predicted_row1:predicted_row2, 12] = reversed_attr_10

# %%
submission_df=submission_df.iloc[:30205,:]

# %%
submission_df
# Out:
#        id Category  len Attribute_1 Attribute_2 Attribute_3 Attribute_4  \
# 0     NaN      NaN  NaN         NaN         NaN         NaN         NaN
# 1     NaN      NaN  NaN         NaN         NaN         NaN         NaN
# 2     NaN      NaN  NaN         NaN         NaN         NaN         NaN
# 3     NaN      NaN  NaN         NaN         NaN         NaN         NaN
# 4     NaN      NaN  NaN         NaN         NaN         NaN         NaN
# ...    ..      ...  ...         ...         ...         ...         ...
# 30200 NaN      NaN  NaN         NaN         NaN         NaN         NaN
# 30201 NaN      NaN  NaN         NaN         NaN         NaN         NaN
# 30202 NaN      NaN  NaN         NaN         NaN         NaN         NaN
# 30203 NaN      NaN  NaN         NaN         NaN         NaN         NaN
# 30204 NaN      NaN  NaN         NaN         NaN         NaN         NaN
#
#       Attribute_5 Attribute_6 Attribute_7 Attribute_8 Attribute_9 Attribute_10
# 0             NaN         NaN         NaN         NaN         NaN          NaN
# 1             NaN         NaN         NaN         NaN         NaN          NaN
# 2             NaN         NaN         NaN         NaN         NaN          NaN
# 3             NaN         NaN         NaN         NaN         NaN          NaN
# 4             NaN         NaN         NaN         NaN         NaN          NaN
# ...           ...         ...         ...         ...         ...          ...
# 30200         NaN         NaN         NaN         NaN         NaN          NaN
# 30201         NaN         NaN         NaN         NaN         NaN          NaN
# 30202         NaN         NaN         NaN         NaN         NaN          NaN
# 30203         NaN         NaN         NaN         NaN         NaN          NaN
# 30204         NaN         NaN         NaN         NaN         NaN          NaN
#
# [30205 rows x 13 columns]

# %%
submission_df.iloc[predicted_row1:predicted_row2]
# Out:
#             id Category   len  Attribute_1 Attribute_2   Attribute_3  \
# 3787    3787.0   Sarees  10.0  dummy_value        zari  small border
# 3788    3788.0   Sarees  10.0  dummy_value        zari  small border
# 3789    3789.0   Sarees  10.0  dummy_value        zari  small border
# 3790    3790.0   Sarees  10.0  dummy_value        zari  small border
# 3791    3791.0   Sarees  10.0  dummy_value        zari  small border
# ...        ...      ...   ...          ...         ...           ...
# 10884  11150.0   Sarees  10.0  dummy_value        zari  small border
# 10885  11151.0   Sarees  10.0  dummy_value        zari  small border
# 10886  11152.0   Sarees  10.0  dummy_value        zari  small border
# 10887  11153.0   Sarees  10.0  dummy_value        zari  small border
# 10888  11154.0   Sarees  10.0  dummy_value        zari  small border
#
#       Attribute_4 Attribute_5  Attribute_6  Attribute_7 Attribute_8  \
# 3787   multicolor       party  dummy_value  dummy_value  zari woven
# 3788   multicolor       party  dummy_value  dummy_value  zari woven
# 3789   multicolor       party  dummy_value  dummy_value  zari woven
# 3790   multicolor       party  dummy_value  dummy_value  zari woven
# 3791   multicolor       party  dummy_value  dummy_value  zari woven
# ...           ...         ...          ...          ...         ...
# 10884  multicolor       party  dummy_value  dummy_value  zari woven
# 10885  multicolor       party  dummy_value  dummy_value  zari woven
# 10886  multicolor       party  dummy_value  dummy_value  zari woven
# 10887  multicolor       party  dummy_value  dummy_value  zari woven
# 10888  multicolor       party  dummy_value  dummy_value  zari woven
#
#        Attribute_9 Attribute_10
# 3787   dummy_value           no
# 3788   dummy_value           no
# 3789   dummy_value           no
# 3790   dummy_value           no
# 3791   dummy_value           no
# ...            ...          ...
# 10884  dummy_value           no
# 10885  dummy_value           no
# 10886  dummy_value           no
# 10887  dummy_value           no
# 10888  dummy_value           no
#
# [7102 rows x 13 columns]

# %%
submission_df.fillna('nu', inplace=True)
# Out:
# /tmp/ipykernel_30/2203038571.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nu' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   submission_df.fillna('nu', inplace=True)

# %%
submission_df.iloc[:30205,0] = test_text.iloc[:,0]
submission_df.iloc[:30205,1] = test_text.iloc[:,1]

# %%
# Rename columns
submission_df.rename(columns={
    'Attribute_1': 'attr_1',
    'Attribute_2': 'attr_2',
    'Attribute_3': 'attr_3',
    'Attribute_4': 'attr_4',
    'Attribute_5': 'attr_5',
    'Attribute_6': 'attr_6',
    'Attribute_7': 'attr_7',
    'Attribute_8': 'attr_8',
    'Attribute_9': 'attr_9',
    'Attribute_10': 'attr_10',
}, inplace=True)

# %%
submission_df
# Out:
#           id             Category len attr_1 attr_2 attr_3 attr_4 attr_5  \
# 0          0          Men Tshirts  nu     nu     nu     nu     nu     nu
# 1          1          Men Tshirts  nu     nu     nu     nu     nu     nu
# 2          2          Men Tshirts  nu     nu     nu     nu     nu     nu
# 3          3          Men Tshirts  nu     nu     nu     nu     nu     nu
# 4          4          Men Tshirts  nu     nu     nu     nu     nu     nu
# ...      ...                  ...  ..    ...    ...    ...    ...    ...
# 30200  30484  Women Tops & Tunics  nu     nu     nu     nu     nu     nu
# 30201  30485  Women Tops & Tunics  nu     nu     nu     nu     nu     nu
# 30202  30486  Women Tops & Tunics  nu     nu     nu     nu     nu     nu
# 30203  30487  Women Tops & Tunics  nu     nu     nu     nu     nu     nu
# 30204  30488  Women Tops & Tunics  nu     nu     nu     nu     nu     nu
#
#       attr_6 attr_7 attr_8 attr_9 attr_10
# 0         nu     nu     nu     nu      nu
# 1         nu     nu     nu     nu      nu
# 2         nu     nu     nu     nu      nu
# 3         nu     nu     nu     nu      nu
# 4         nu     nu     nu     nu      nu
# ...      ...    ...    ...    ...     ...
# 30200     nu     nu     nu     nu      nu
# 30201     nu     nu     nu     nu      nu
# 30202     nu     nu     nu     nu      nu
# 30203     nu     nu     nu     nu      nu
# 30204     nu     nu     nu     nu      nu
#
# [30205 rows x 13 columns]

# %%
men_tshirt_sub=pd.read_csv('/kaggle/input/submission-files/submission_MEN_TSHIRTS.csv')
men_tshirt_sub
# Out:
#           id             Category  len      attr_1       attr_2   attr_3  \
# 0          0          Men Tshirts  5.0     default        round  printed
# 1          1          Men Tshirts  5.0     default        round  printed
# 2          2          Men Tshirts  5.0     default        round    solid
# 3          3          Men Tshirts  5.0  multicolor         polo    solid
# 4          4          Men Tshirts  5.0  multicolor  dummy_value    solid
# ...      ...                  ...  ...         ...          ...      ...
# 30200  30484  Women Tops & Tunics   nu          nu           nu       nu
# 30201  30485  Women Tops & Tunics   nu          nu           nu       nu
# 30202  30486  Women Tops & Tunics   nu          nu           nu       nu
# 30203  30487  Women Tops & Tunics   nu          nu           nu       nu
# 30204  30488  Women Tops & Tunics   nu          nu           nu       nu
#
#         attr_4         attr_5       attr_6       attr_7       attr_8  \
# 0      default  short sleeves  dummy_value  dummy_value  dummy_value
# 1      default  short sleeves  dummy_value  dummy_value  dummy_value
# 2      default  short sleeves  dummy_value  dummy_value  dummy_value
# 3        solid  short sleeves  dummy_value  dummy_value  dummy_value
# 4        solid  short sleeves  dummy_value  dummy_value  dummy_value
# ...        ...            ...          ...          ...          ...
# 30200       nu             nu           nu           nu           nu
# 30201       nu             nu           nu           nu           nu
# 30202       nu             nu           nu           nu           nu
# 30203       nu             nu           nu           nu           nu
# 30204       nu             nu           nu           nu           nu
#
#             attr_9      attr_10
# 0      dummy_value  dummy_value
# 1      dummy_value  dummy_value
# 2      dummy_value  dummy_value
# 3      dummy_value  dummy_value
# 4      dummy_value  dummy_value
# ...            ...          ...
# 30200           nu           nu
# 30201           nu           nu
# 30202           nu           nu
# 30203           nu           nu
# 30204           nu           nu
#
# [30205 rows x 13 columns]

# %%
submission_df.iloc[:3787]=men_tshirt_sub.iloc[:3787]

# %%
submission_df.iloc[:10889]
# Out:
#           id     Category   len       attr_1       attr_2        attr_3  \
# 0          0  Men Tshirts   5.0      default        round       printed
# 1          1  Men Tshirts   5.0      default        round       printed
# 2          2  Men Tshirts   5.0      default        round         solid
# 3          3  Men Tshirts   5.0   multicolor         polo         solid
# 4          4  Men Tshirts   5.0   multicolor  dummy_value         solid
# ...      ...          ...   ...          ...          ...           ...
# 10884  11150       Sarees  10.0  dummy_value         zari  small border
# 10885  11151       Sarees  10.0  dummy_value         zari  small border
# 10886  11152       Sarees  10.0  dummy_value         zari  small border
# 10887  11153       Sarees  10.0  dummy_value         zari  small border
# 10888  11154       Sarees  10.0  dummy_value         zari  small border
#
#            attr_4         attr_5       attr_6       attr_7       attr_8  \
# 0         default  short sleeves  dummy_value  dummy_value  dummy_value
# 1         default  short sleeves  dummy_value  dummy_value  dummy_value
# 2         default  short sleeves  dummy_value  dummy_value  dummy_value
# 3           solid  short sleeves  dummy_value  dummy_value  dummy_value
# 4           solid  short sleeves  dummy_value  dummy_value  dummy_value
# ...           ...            ...          ...          ...          ...
# 10884  multicolor          party  dummy_value  dummy_value   zari woven
# 10885  multicolor          party  dummy_value  dummy_value   zari woven
# 10886  multicolor          party  dummy_value  dummy_value   zari woven
# 10887  multicolor          party  dummy_value  dummy_value   zari woven
# 10888  multicolor          party  dummy_value  dummy_value   zari woven
#
#             attr_9      attr_10
# 0      dummy_value  dummy_value
# 1      dummy_value  dummy_value
# 2      dummy_value  dummy_value
# 3      dummy_value  dummy_value
# 4      dummy_value  dummy_value
# ...            ...          ...
# 10884  dummy_value           no
# 10885  dummy_value           no
# 10886  dummy_value           no
# 10887  dummy_value           no
# 10888  dummy_value           no
#
# [10889 rows x 13 columns]

# %%
submission_df
# Out:
#           id             Category  len      attr_1       attr_2   attr_3  \
# 0          0          Men Tshirts  5.0     default        round  printed
# 1          1          Men Tshirts  5.0     default        round  printed
# 2          2          Men Tshirts  5.0     default        round    solid
# 3          3          Men Tshirts  5.0  multicolor         polo    solid
# 4          4          Men Tshirts  5.0  multicolor  dummy_value    solid
# ...      ...                  ...  ...         ...          ...      ...
# 30200  30484  Women Tops & Tunics   nu          nu           nu       nu
# 30201  30485  Women Tops & Tunics   nu          nu           nu       nu
# 30202  30486  Women Tops & Tunics   nu          nu           nu       nu
# 30203  30487  Women Tops & Tunics   nu          nu           nu       nu
# 30204  30488  Women Tops & Tunics   nu          nu           nu       nu
#
#         attr_4         attr_5       attr_6       attr_7       attr_8  \
# 0      default  short sleeves  dummy_value  dummy_value  dummy_value
# 1      default  short sleeves  dummy_value  dummy_value  dummy_value
# 2      default  short sleeves  dummy_value  dummy_value  dummy_value
# 3        solid  short sleeves  dummy_value  dummy_value  dummy_value
# 4        solid  short sleeves  dummy_value  dummy_value  dummy_value
# ...        ...            ...          ...          ...          ...
# 30200       nu             nu           nu           nu           nu
# 30201       nu             nu           nu           nu           nu
# 30202       nu             nu           nu           nu           nu
# 30203       nu             nu           nu           nu           nu
# 30204       nu             nu           nu           nu           nu
#
#             attr_9      attr_10
# 0      dummy_value  dummy_value
# 1      dummy_value  dummy_value
# 2      dummy_value  dummy_value
# 3      dummy_value  dummy_value
# 4      dummy_value  dummy_value
# ...            ...          ...
# 30200           nu           nu
# 30201           nu           nu
# 30202           nu           nu
# 30203           nu           nu
# 30204           nu           nu
#
# [30205 rows x 13 columns]

# %%
# Save the DataFrame to a CSV file
submission_file = 'submission_first2_categories.csv'
submission_df.to_csv(submission_file, index=False)

print("Submission file created successfully!")
# Out:
# Submission file created successfully!
